# %% [markdown]
# 	# Author: Alexander Staub
# 	## Last changed: 2023.03.21
# 	## Purpose: Accessing the Spotify API

# %% [markdown]
# # Done to dos:
# * rate limits: some links suggested a 180/minute rate limit
# * changed the .append to .concat in the loop to avoid warnings
# * added the audio feature elements from spotify - all of them according to gpt-4

# %% [markdown]
# # Next up to dos - 23.03.28
#
# * with the first random sample, a number of songs were not matched. Think of a way to get all the songs that weren't matched into a seperate dataframe

# %%
#library loading

import os
import spotipy # lightweight Python library for the Spotify Web API
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials # to access authorised Spotify data
import json # to read json files
import time # to time the code
import requests # to make http requests

# %%
# path specification - using os

from path_specification import root_dir

# %% [markdown]
# Load the system path for the src folder where reusable .py scripts are located

# %%
# get the client id and client secret for my account
import sys

# Assuming root_dir contains the path to your project's root directory
sys.path.append(f"{root_dir}/code/src")

# %% [markdown]
# Load in your spotify access credentials

# %%
# get the client id and client secret for my account

# access the spotify credentials from the json file and store it as variable "f"
with open('spotify_credentials.json') as f:

    # transform the json file into a dictionary
    data = json.load(f)
    client_id = data['SPOTIPY_CLIENT_ID']
    client_secret = data['SPOTIPY_CLIENT_SECRET']

if not client_id or not client_secret:
    raise ValueError("Spotify API credentials not found in environment variables")

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
# load in the random sample w isrcs into a dataframe

# Create the path to the CSV file
csv_file_path = os.path.join(root_dir, 'data', 'interim_data', 'random_sample_w_iscrcs_mb_v5_export.csv')

#create the json file path
json_file_path = os.path.join(root_dir, 'data', 'raw_data','musicbrainz', 'isrcs_from_release_with_label_v6.json')

# %% [markdown]
# Below is the code to read in a csv - created when interested in analyzing a random sample

# %%
#detect the encoding of the csv

import chardet    

rawdata = open(csv_file_path, "rb").read()
result = chardet.detect(rawdata)
charenc = result['encoding']

# %%
# Now read the CSV into a DataFrame
sample_songs_w_isrcs = pd.read_csv(csv_file_path, encoding=charenc)

#remove the column named "unnamed" from the sample_songs_w_isrcs dataframe
sample_songs_w_isrcs = sample_songs_w_isrcs.loc[:, ~sample_songs_w_isrcs.columns.str.contains('^Unnamed')]

# %% [markdown]
# Currently, the loaded dataframe includes variables of the type "object" - which means that they are some generic form of data type.
# Converting all but date to string will make it easier to access spotify API

# %%
#loop through all variables and convert them to strings - except the date column
for col in sample_songs_w_isrcs.columns:
    if col != 'date':
        sample_songs_w_isrcs[col] = sample_songs_w_isrcs[col].astype(str)

# %% [markdown]
# Below is the code for reading in the json based dataframe including isrcs from all US released songs in the timeframe of interest

# %%
# read in json file
us_songs_w_isrcs = pd.read_json(json_file_path)

# %%
# drop the last column
us_songs_w_isrcs = us_songs_w_isrcs.iloc[:, :-1]

# %%
#loop through all variables and convert them to strings - except the date column
for col in us_songs_w_isrcs.columns:
    if col != 'release_date':
        us_songs_w_isrcs[col] = us_songs_w_isrcs[col].astype(str)

# %% [markdown]
# The code below is meant to:
# - check the ISRC codes in the musicbrainz dataframe and collect the name of thesong, artist and acoustic charactersitics from the Spotify Api
# - respect the rate limits of 10 requests per second
# - save the data periodically in case of some error
# - collect data about unmatched isrcs in a seperate file for later review
# - not restart from 0 in case the operation fails, but check what was already collected

# %%
# create the save path
save_path = os.path.join(root_dir, "data", "interim_data", "spotify_isrc_sample")

print(save_path)
# Out:
# c:\Users\User\Documents\R_Work\research\music_data\data\interim_data\spotify_isrc_sample

# %%
#try whether the the dataframe already exists or whether it needs to be created

# Try whether the dataframe already exists or whether it needs to be created
try:
    df_spotify = pd.read_csv(os.path.join(save_path, "partial_spotify_data.csv"))
except (FileNotFoundError, pd.errors.EmptyDataError):  # Catching both exceptions
    df_spotify = pd.DataFrame()

try:
    with open(os.path.join(save_path, "unmatched_isrcs.json"), "r") as f:
        unmatched_isrcs = json.load(f)
except FileNotFoundError:
    unmatched_isrcs = []

# List to hold dictionaries to append to df_spotify
data_to_append = []

# %% [markdown]
# Code to run if a manual reset of the dataframes is desired
#
# Uncomment if needed

# %%
# empty list for the matched isrcs
# df_spotify = pd.DataFrame()

# empty list for the unmatched isrcs
# unmatched_isrcs = []

# List to hold dictionaries to append to df_spotify
# data_to_append = []

# %%
#check 
us_songs_w_isrcs.describe()

# check how many NA values are present by column in the us_songs_w_isrcs dataframe
us_songs_w_isrcs.isna().sum()
# Out:
# isrc                  0
# track_id              0
# track_title           0
# artist_name           0
# artist_mbid           0
# release_mbid          0
# release_group_mbid    0
# release_date          0
# dtype: int64

# %%
#create the startpoint at 0
start_point = 0

# %%
# Track where you are in the loop in case you have to restart
try:
    # Check if a start_point file exists (this assumes the file holds an integer)
    with open(os.path.join(save_path, "start_point.txt"), "r") as f:
        start_point = int(f.read())
except FileNotFoundError:
    pass

# %% [markdown]
# Tenacity based rate limiting with exponential wait times - might be causing an issue

# %%
from tenacity import retry, stop_after_attempt, wait_exponential
import time

@retry(stop=stop_after_attempt(5), wait=wait_exponential(multiplier=1, min=5, max=60))
def fetch_track_data(isrc):
    time.sleep(1)  # Slow down to 1 requests per second
    return sp.search(q=f'isrc:{isrc}', type='track')

@retry(stop=stop_after_attempt(5), wait=wait_exponential(multiplier=1, min=5, max=60))
def fetch_audio_features(spotify_id):
    time.sleep(1)  # Slow down to 4 requests per second
    return sp.audio_features(spotify_id)[0]

# %% [markdown]
# Alternative, less sophisticated rate limiting to check if tenacity is causing the problem or if I have been blocked from this IP address

# %%
import time

def fetch_audio_features(spotify_id):
    for _ in range(5):
        time.sleep(1)  # Wait 1/3 of a second before making the request
        try:
            return sp.audio_features(spotify_id)[0]
        except requests.exceptions.HTTPError as err:
            print(f"Error, will retry: {err}")
            time.sleep(5)  # 5 seconds delay before retry
    print("Max retries reached")
    return None

# %%
# Replace 'us_songs_w_isrcs' with your actual DataFrame containing ISRCs
for i, row in us_songs_w_isrcs.iloc[start_point:].iterrows():
    
    isrc = row['isrc']
    
    try:
        # Search for track by ISRC
        results = fetch_track_data(isrc)
        
        # Check if the search returned any tracks
        if results['tracks']['items']:
            track = results['tracks']['items'][0]
            
            # Fetch audio features using Spotify ID
            audio_features = fetch_audio_features(track["id"])

            # Extract and append only the acoustic features and ISRC to data_to_append
            if audio_features is not None:
                audio_features["ISRC"] = isrc
                data_to_append.append(audio_features)
            else:
                print(f"Audio features missing for ISRC: {isrc}")
                unmatched_isrcs.append((i, isrc))
        else:
            print(f"Couldn't match ISRC: {isrc}")
            unmatched_isrcs.append((i, isrc))

    except requests.exceptions.HTTPError as err:
        print(f"HTTP Error for ISRC: {isrc}, Error: {err}")
        unmatched_isrcs.append((i, isrc))
        
    # You may also want to save your results periodically to a CSV or JSON
    if i % 100 == 0:
        pd.DataFrame(data_to_append).to_csv(os.path.join(save_path, "partial_spotify_data.csv"), index=False)
        with open(os.path.join(save_path, "unmatched_isrcs.json"), "w") as f:
            json.dump(unmatched_isrcs, f)

# Convert the list of dictionaries to a DataFrame
if data_to_append:
    df_spotify = pd.DataFrame(data_to_append)

# Save your results
df_spotify.to_csv(os.path.join(save_path, "complete_spotify_data.csv"), index=False)
with open(os.path.join(save_path, "unmatched_isrcs.json"), "w") as f:
    json.dump(unmatched_isrcs, f)
# Out:
# Couldn't match ISRC: USMJ19801474
# Couldn't match ISRC: USMJ19801490
# Couldn't match ISRC: USMJ19801475
# Couldn't match ISRC: USMJ19801476
# Couldn't match ISRC: USMJ19801477
# Couldn't match ISRC: USMJ19801358
# Couldn't match ISRC: USMJ19801478
# Couldn't match ISRC: USMJ19801479
# Couldn't match ISRC: USMJ19801480
# Couldn't match ISRC: USMJ19801481
# Couldn't match ISRC: USMJ19801482
# Couldn't match ISRC: USMJ19801483
# Couldn't match ISRC: USMJ19801484
# Couldn't match ISRC: USMJ19801485
# Couldn't match ISRC: USMJ19801486
# Couldn't match ISRC: USMJ19801487
# Couldn't match ISRC: USMJ19801488
# Couldn't match ISRC: USMJ19801474
# Couldn't match ISRC: USMJ19801490
# Couldn't match ISRC: USMJ19801475
# Couldn't match ISRC: USMJ19801476
# Couldn't match ISRC: USMJ19801477
# Couldn't match ISRC: USMJ19801358
# Couldn't match ISRC: USMJ19801478
# Couldn't match ISRC: USMJ19801479
# Couldn't match ISRC: USMJ19801480
# Couldn't match ISRC: USMJ19801481
# Couldn't match ISRC: USMJ19801482
# Couldn't match ISRC: USMJ19801483
# Couldn't match ISRC: USMJ19801484
# Couldn't match ISRC: USMJ19801485
# Couldn't match ISRC: USMJ19801486
# Couldn't match ISRC: GBBUF9800292
# Couldn't match ISRC: GBBUF9800351
# Couldn't match ISRC: GBBUF9800354
# Couldn't match ISRC: SEAYD7704020
# Couldn't match ISRC: SEAYD7890001
# Couldn't match ISRC: USAT20612675
# Couldn't match ISRC: SEAYD7702070
# Couldn't match ISRC: SEAYD7790004
# Couldn't match ISRC: GBDNH0400383
# Couldn't match ISRC: GBDNH0400373
# Couldn't match ISRC: GBDNH0400601
# Couldn't match ISRC: USAT20110520
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606190
# Couldn't match ISRC: JPKI00409181
# Couldn't match ISRC: JPKI09519980
# Couldn't match ISRC: JPKI00409183
# Couldn't match ISRC: JPKI09528550
# Couldn't match ISRC: JPKI00409185
# Couldn't match ISRC: JPKI00409188
# Couldn't match ISRC: JPKI09519989
# Couldn't match ISRC: JPKI00409189
# Couldn't match ISRC: JPKI09519979
# Couldn't match ISRC: JPKI00409192
# Couldn't match ISRC: JPKI09528560
# Couldn't match ISRC: JPKI00312413
# Couldn't match ISRC: JPKI09606180
# Couldn't match ISRC: JPKI09606200
# Couldn't match ISRC: JPKI09606210
# Couldn't match ISRC: JPKI09606220
# Couldn't match ISRC: JPKI09606230
# Couldn't match ISRC: USA561399610
# Couldn't match ISRC: USA561399616
# Couldn't match ISRC: JPKI09519970
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09541180
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI09522460
# Couldn't match ISRC: JPKI01419610
# Couldn't match ISRC: JPKI09716700
# Couldn't match ISRC: JPKI01419611
# Couldn't match ISRC: JPKI09716700
# Couldn't match ISRC: JPKI01419612
# Couldn't match ISRC: JPKI09716700
# Couldn't match ISRC: JPKI01419613
# Couldn't match ISRC: JPKI09716700
# Couldn't match ISRC: JPKI01419614
# Couldn't match ISRC: JPKI09716700
# Couldn't match ISRC: JPKI01419615
# Couldn't match ISRC: JPKI01419616
# Couldn't match ISRC: JPKI09716700
# Couldn't match ISRC: JPKI01419617
# Couldn't match ISRC: JPKI01419618
# Couldn't match ISRC: JPKI09716700
# Couldn't match ISRC: JPKI01419619
# Couldn't match ISRC: JPKI09716700
# Couldn't match ISRC: JPKI01419620
# Couldn't match ISRC: JPKI01419621
# Couldn't match ISRC: JPKI01419622
# Couldn't match ISRC: JPKI09716700
# Couldn't match ISRC: JPKI01419623
# Couldn't match ISRC: JPKI09716700
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI00409163
# Couldn't match ISRC: JPKI09519970
# Couldn't match ISRC: JPKI09528530
# Couldn't match ISRC: JPKI09528540
# Couldn't match ISRC: JPKI09528520
# Couldn't match ISRC: JPKI09528550
# Couldn't match ISRC: JPKI09528560
# Couldn't match ISRC: JPKI09817530
# Couldn't match ISRC: JPKI09819360
# Couldn't match ISRC: GBF088590131
# Couldn't match ISRC: USRHD1100541
# Couldn't match ISRC: JPA840601537
# Couldn't match ISRC: JPA840700011
# Couldn't match ISRC: JPA842100691
# Couldn't match ISRC: JPA840700012
# Couldn't match ISRC: JPA840700013
# Couldn't match ISRC: JPA840700015
# Couldn't match ISRC: JPA842100744
# Couldn't match ISRC: USBMG0700650
# Couldn't match ISRC: GBAAP8000005
# Couldn't match ISRC: GBAAP8000439
# Couldn't match ISRC: GBAAP8000015
# Couldn't match ISRC: GBBLG8000435
# Couldn't match ISRC: GBAAP8000006
# Couldn't match ISRC: GBAAP8000017
# Couldn't match ISRC: GBAAP8100001
# Couldn't match ISRC: GBAAP8200002
# Couldn't match ISRC: GBAAP8000008
# Couldn't match ISRC: GBBLG8000429
# Couldn't match ISRC: GBAAP8100006
# Couldn't match ISRC: GBAAP8200008
# Couldn't match ISRC: GBAAP8200005
# Couldn't match ISRC: GBAAP8000010
# Couldn't match ISRC: GBBLG8000431
# Couldn't match ISRC: GBAAP8000014
# Couldn't match ISRC: GBBLG8000434
# Couldn't match ISRC: USRE11500103
# Couldn't match ISRC: USRE11500141
# Couldn't match ISRC: USRE11500125
# Couldn't match ISRC: USEDD0310231
# Couldn't match ISRC: GBAYE9800238
# Couldn't match ISRC: GBCHB0010092
# Couldn't match ISRC: USSM10108685
# Couldn't match ISRC: USSM10108687
# Couldn't match ISRC: USSM10108688
# Couldn't match ISRC: GBAYE9800241
# Couldn't match ISRC: USSM10108686
# Couldn't match ISRC: USSM10108689
# Couldn't match ISRC: USSM10108690
# Couldn't match ISRC: USSM10108691
# Couldn't match ISRC: USSM10108692
# Couldn't match ISRC: GBCHB0300299
# Couldn't match ISRC: GBCHB0300300
# Couldn't match ISRC: GBCHB0300301
# Couldn't match ISRC: GBCHB0300302
# Couldn't match ISRC: GBCHB0300303
# Couldn't match ISRC: GBCHB0300304
# Couldn't match ISRC: GBCHB0300305
# Couldn't match ISRC: GBCHB0300306
# Couldn't match ISRC: GBCHB0300307
# Couldn't match ISRC: GBCHB0300308
# Couldn't match ISRC: GBCHB0300309
# Couldn't match ISRC: GB5KW2102648
# Couldn't match ISRC: GB5KW2102649
# Couldn't match ISRC: GB0200102062
# Couldn't match ISRC: GB5KW2102650
# Couldn't match ISRC: GB5KW2102651
# Couldn't match ISRC: GB5KW2102652
# Couldn't match ISRC: GB5KW2102653
# Couldn't match ISRC: GB5KW2102654
# Couldn't match ISRC: GB5KW2102655
# Couldn't match ISRC: GB5KW2102656
# Couldn't match ISRC: GB5KW2102657
# Couldn't match ISRC: GB5KW2102658
# Couldn't match ISRC: GB5KW2102660
# Couldn't match ISRC: GB5KW2102663
# Couldn't match ISRC: GB5KW2102667
# Couldn't match ISRC: GB5KW2102664
# Couldn't match ISRC: GBBBM0102120
# Couldn't match ISRC: GB5KW2102665
# Couldn't match ISRC: GBBBM0102127
# Couldn't match ISRC: DEZ900501009
# Couldn't match ISRC: NLC280310039
# Couldn't match ISRC: US56V0505302
# Couldn't match ISRC: USCGH1701197
# Couldn't match ISRC: USCGH1701198
# Couldn't match ISRC: USCGH1701199
# Couldn't match ISRC: USCGH1701200
# Couldn't match ISRC: USCGH1701201
# Couldn't match ISRC: USCGH1701202
# Couldn't match ISRC: USCGH1701203
# Couldn't match ISRC: USCGH1701204
# Couldn't match ISRC: USCGH1701205
# Couldn't match ISRC: USSM17100570
# Couldn't match ISRC: USSM17500770
# Couldn't match ISRC: USWB17500770
# Couldn't match ISRC: SEPQA1300215
# Couldn't match ISRC: USSM16301328
# Couldn't match ISRC: USKO10701605
# Couldn't match ISRC: GBARL0800241
# Couldn't match ISRC: GBARL0800257
# Couldn't match ISRC: GBARL0800450
# Couldn't match ISRC: GBCEL2000160
# Couldn't match ISRC: GBBEU9600006
# Couldn't match ISRC: GBAWV0103330
# Couldn't match ISRC: USSM10407318
# Couldn't match ISRC: USCA20400579
# Couldn't match ISRC: USJAY0400093
# Couldn't match ISRC: GBEGS0300074
# Couldn't match ISRC: USSM10408032
# Couldn't match ISRC: USDW10400758
# Couldn't match ISRC: USRH10450226
# Couldn't match ISRC: USRH10450227
# Couldn't match ISRC: USRH10450228
# Couldn't match ISRC: USRH10450229
# Couldn't match ISRC: USRH10450230
# Couldn't match ISRC: USRH10450231
# Couldn't match ISRC: USRH10450232
# Couldn't match ISRC: USRH10450233
# Couldn't match ISRC: USRH10450235
# Couldn't match ISRC: USRH10450236
# Couldn't match ISRC: USRH10450237
# Couldn't match ISRC: USRH10450238
# Couldn't match ISRC: USRH10450239
# Couldn't match ISRC: GB5KW1800060
# Couldn't match ISRC: GBAJH0800092
# Couldn't match ISRC: GBAJH9600224
# Couldn't match ISRC: USLS50481035
# Couldn't match ISRC: GB5KW1800071
# Couldn't match ISRC: GBAJH0800105
# Couldn't match ISRC: GB5KW1800065
# Couldn't match ISRC: GBAJH0800099
# Couldn't match ISRC: GBAJH9600234
# Couldn't match ISRC: GB5KW1800058
# Couldn't match ISRC: GBAJH0800090
# Couldn't match ISRC: GB5KW1800061
# Couldn't match ISRC: GBAJH0800093
# Couldn't match ISRC: GB5KW1800073
# Couldn't match ISRC: GBAJH0800107
# Couldn't match ISRC: GBAJH0400476
# Couldn't match ISRC: GBAJH0800097
# Couldn't match ISRC: GBAJH9600227
# Couldn't match ISRC: GB5KW1800068
# Couldn't match ISRC: GBAJH0800102
# Couldn't match ISRC: GB5KW1800062
# Couldn't match ISRC: GBAJH0800094
# Couldn't match ISRC: GB5KW1800063
# Couldn't match ISRC: GBAJH0600167
# Couldn't match ISRC: GBAJH0800095
# Couldn't match ISRC: GBAJH0800143
# Couldn't match ISRC: GBAJH0800150
# Couldn't match ISRC: GBAJK9900403
# Couldn't match ISRC: US3M51005954
# Couldn't match ISRC: GB5KW1801217
# Couldn't match ISRC: GBAJK9900403
# Couldn't match ISRC: USAT20804457
# Couldn't match ISRC: USAT20804458
# Couldn't match ISRC: USAT20804461
# Couldn't match ISRC: USAT20804464
# Couldn't match ISRC: USAT20804465
# Couldn't match ISRC: USAT20804466
# Couldn't match ISRC: USAT20804467
# Couldn't match ISRC: USAT20804469
# Couldn't match ISRC: USAT20804470
# Couldn't match ISRC: USAT20804471
# Couldn't match ISRC: USAT20804472
# Couldn't match ISRC: USAT20804473
# Couldn't match ISRC: USAT20804474
# Couldn't match ISRC: USAT20804475
# Couldn't match ISRC: USAT20804476
# Couldn't match ISRC: USAT20804477
# Couldn't match ISRC: USAT20804478
# Couldn't match ISRC: GBAJE0300266
# Couldn't match ISRC: GBAJE0201105
# Couldn't match ISRC: USBD70200004
# Couldn't match ISRC: GBAJE0501699
# Couldn't match ISRC: GBAJE0501700
# Couldn't match ISRC: GBAJE0501701
# Couldn't match ISRC: GBAJE0501702
# Couldn't match ISRC: GBAJE0501703
# Couldn't match ISRC: GBAJE0501704
# Couldn't match ISRC: GBAJE0501705
# Couldn't match ISRC: GBAJE0501706
# Couldn't match ISRC: GBAJE0501707
# Couldn't match ISRC: GBAJE0501708
# Couldn't match ISRC: GBAJE0505203
# Couldn't match ISRC: GBAJE0501709
# Couldn't match ISRC: US3M50890058
# Couldn't match ISRC: USCA20000796
# Couldn't match ISRC: USMB30204569
# Couldn't match ISRC: USMB30204574
# Couldn't match ISRC: USCA20000860
# Couldn't match ISRC: DEM090200096
# Couldn't match ISRC: DEM090200097
# Audio features missing for ISRC: DEM090200099
# Couldn't match ISRC: GBAJE8100026
# Couldn't match ISRC: GBAJE0401394
# Couldn't match ISRC: GBAJE8200344
# Couldn't match ISRC: USRC15500012
# Couldn't match ISRC: USWSP0500012
# Couldn't match ISRC: USRC15500030
# Couldn't match ISRC: USWSP0500030
# Couldn't match ISRC: USRC15500034
# Couldn't match ISRC: USWSP0500034
# Couldn't match ISRC: USAT20615657
# Couldn't match ISRC: USBMG0800109
# Couldn't match ISRC: USVT10000110
# Couldn't match ISRC: GB5WK1499390
# Couldn't match ISRC: USEE10000992
# Couldn't match ISRC: USEE19792088
# Couldn't match ISRC: USEE10000876
# Couldn't match ISRC: USEE19693705
# Couldn't match ISRC: USEE10000840
# Couldn't match ISRC: USEE19792090
# Couldn't match ISRC: USEE10000877
# Couldn't match ISRC: USEE10000994
# Couldn't match ISRC: USEE10000878
# Couldn't match ISRC: USEE19574018
# Couldn't match ISRC: GBAJH9700265
# Couldn't match ISRC: USEE19574011
# Couldn't match ISRC: USEE19792087
# Couldn't match ISRC: USEE10000879
# Couldn't match ISRC: USEE10000880
# Couldn't match ISRC: USEE10000996
# Couldn't match ISRC: USEE19693714
# Couldn't match ISRC: USEE19792094
# Couldn't match ISRC: GBAYE9300702
# Couldn't match ISRC: GBAYE9300703
# Couldn't match ISRC: GBAYE9300694
# Couldn't match ISRC: GBAYE9300693
# Couldn't match ISRC: GBAYE9500664
# Couldn't match ISRC: USLR29810286
# Couldn't match ISRC: USLR29810288
# Couldn't match ISRC: USLR29810290
# Couldn't match ISRC: USLR29810291
# Couldn't match ISRC: USLR29810292
# Couldn't match ISRC: GBAQH9800113
# Couldn't match ISRC: DEA349900689
# Couldn't match ISRC: DEC649500253
# Couldn't match ISRC: USAT21601139
# Couldn't match ISRC: DEC768300008
# Couldn't match ISRC: USUV30300091
# Couldn't match ISRC: USSM17500267
# Couldn't match ISRC: USMR19780073
# Couldn't match ISRC: GBF080300553
# Couldn't match ISRC: USGI19900048
# Couldn't match ISRC: USRH10171622
# Couldn't match ISRC: USA278200010
# Couldn't match ISRC: USF068200020
# Couldn't match ISRC: USVT10000110
# Couldn't match ISRC: GBAJH9900614
# Couldn't match ISRC: GBHCD1711370
# Couldn't match ISRC: GBAJH0000165
# Couldn't match ISRC: GBAJH9900452
# Couldn't match ISRC: USVT10200146
# Couldn't match ISRC: USVT10300111
# Couldn't match ISRC: GBAJH0300210
# Couldn't match ISRC: USVT10300116
# Couldn't match ISRC: USVT10300117
# Couldn't match ISRC: USVT10300118
# Couldn't match ISRC: USVT10300119
# Couldn't match ISRC: USVT10300120
# Couldn't match ISRC: USVT10300121
# Couldn't match ISRC: USVT10300122
# Couldn't match ISRC: USVT10300123
# Couldn't match ISRC: USVT10300124
# Couldn't match ISRC: USVT10300125
# Couldn't match ISRC: USVT10300126
# Couldn't match ISRC: GBAJH9900225
# Couldn't match ISRC: GB5WK1499392
# Couldn't match ISRC: AUEI10700168
# Couldn't match ISRC: AUMP09800004
# Couldn't match ISRC: AUMP09800005
# Couldn't match ISRC: AUMP09800006
# Couldn't match ISRC: AUMP09800007
# Couldn't match ISRC: AUMP09800008
# Couldn't match ISRC: AUMP09800009
# Couldn't match ISRC: AUMP09800010
# Couldn't match ISRC: AUMP09800001
# Couldn't match ISRC: AUMP09800011
# Couldn't match ISRC: AUMP09800012
# Couldn't match ISRC: AUMP09800013
# Couldn't match ISRC: AUMP09800014
# Couldn't match ISRC: AUMP09800016
# Couldn't match ISRC: AUEMO0000208
# Couldn't match ISRC: AUEMO0000209
# Couldn't match ISRC: AUEMO0000216
# Couldn't match ISRC: AUEI10700168
# Couldn't match ISRC: AUMP09800004
# Couldn't match ISRC: AUMP09800011
# Couldn't match ISRC: AUMP09800010
# Couldn't match ISRC: AUMP09900010
# Couldn't match ISRC: AUMPO9800029
# Couldn't match ISRC: AUEI10700168
# Couldn't match ISRC: AUMP09800004
# Couldn't match ISRC: AUMP09800006
# Couldn't match ISRC: AUMP09800015
# Couldn't match ISRC: AUMP09800002
# Couldn't match ISRC: USSM10701823
# Couldn't match ISRC: USSM18300001
# Couldn't match ISRC: USSM19500144
# Couldn't match ISRC: GBAYE0100394
# Couldn't match ISRC: USSM16400918
# Couldn't match ISRC: USSM16401682
# Couldn't match ISRC: USSM19802331
# Couldn't match ISRC: USBMG0700647
# Couldn't match ISRC: GBAJH9900450
# Couldn't match ISRC: DKBKA9800101
# Couldn't match ISRC: SEAMA1100004
# Couldn't match ISRC: USSM17400578
# Couldn't match ISRC: USSM17400748
# Couldn't match ISRC: GBAAA0400502
# Couldn't match ISRC: GBAAA9820849
# Couldn't match ISRC: GBAKZ7300001
# Couldn't match ISRC: GBAWA0515685
# Couldn't match ISRC: GBF069090126
# Couldn't match ISRC: USSM10018324
# Couldn't match ISRC: USSM19801509
# Couldn't match ISRC: USSM19802681
# Couldn't match ISRC: USRC19101841
# Couldn't match ISRC: GBAAP0500263
# Couldn't match ISRC: USSM19704766
# Couldn't match ISRC: USSM18400909
# Couldn't match ISRC: USSMI8400032
# Couldn't match ISRC: USPR39402397
# Couldn't match ISRC: AUXN22142334
# Couldn't match ISRC: DELJ81808923
# Couldn't match ISRC: TCJPN2170853
# Couldn't match ISRC: USAT20504467
# Couldn't match ISRC: USAT21201313
# Couldn't match ISRC: USAT21203966
# Couldn't match ISRC: USAT21203979
# Couldn't match ISRC: USAT21403673
# Couldn't match ISRC: USLIC0601851
# Couldn't match ISRC: USRH10652588
# Couldn't match ISRC: USSM10026969
# Couldn't match ISRC: USEE11200786
# Couldn't match ISRC: USEE11200806
# Couldn't match ISRC: GBF069009994
# Couldn't match ISRC: GBF069090004
# Couldn't match ISRC: GBFO69009994
# Couldn't match ISRC: NLF059090004
# Couldn't match ISRC: AUEM00300058
# Couldn't match ISRC: USSM19920608
# Couldn't match ISRC: USWB10302237
# Couldn't match ISRC: USWB10302238
# Couldn't match ISRC: USWB10300686
# Couldn't match ISRC: USWB10102658
# Couldn't match ISRC: USWB10302239
# Couldn't match ISRC: USWB19200007
# Couldn't match ISRC: USWB19700641
# Couldn't match ISRC: USWB10302252
# Couldn't match ISRC: USWB10302253
# Couldn't match ISRC: USWB10302254
# Couldn't match ISRC: USWB10100455
# Couldn't match ISRC: USWB10104935
# Couldn't match ISRC: USWB10203682
# Couldn't match ISRC: USSM19920608
# Couldn't match ISRC: USWB11402852
# Couldn't match ISRC: USWB11403541
# Couldn't match ISRC: USWB11402850
# Couldn't match ISRC: USWB11403542
# Couldn't match ISRC: USWB11402757
# Couldn't match ISRC: USWB11403543
# Couldn't match ISRC: USWB11402754
# Couldn't match ISRC: USWB11403544
# Couldn't match ISRC: USWB11403522
# Couldn't match ISRC: USWB11402755
# Couldn't match ISRC: USWB11403545
# Couldn't match ISRC: USWB11402846
# Couldn't match ISRC: USWB11403546
# Couldn't match ISRC: USWB11403547
# Couldn't match ISRC: USWB11402753
# Couldn't match ISRC: USWB11403548
# Couldn't match ISRC: USWB11402844
# Couldn't match ISRC: USWB11403549
# Couldn't match ISRC: USWB11402788
# Couldn't match ISRC: USWB11403550
# Couldn't match ISRC: GBAYK8900042
# Couldn't match ISRC: USWB11403523
# Couldn't match ISRC: USWB18900123
# Couldn't match ISRC: USWB11402799
# Couldn't match ISRC: USWB11403551
# Couldn't match ISRC: USWB11402766
# Couldn't match ISRC: USWB11403552
# Couldn't match ISRC: USWB11403524
# Couldn't match ISRC: USWB11403525
# Couldn't match ISRC: GBAYE0302294
# Couldn't match ISRC: GBAYE0302295
# Couldn't match ISRC: GBAYE0302296
# Couldn't match ISRC: GBAYE0302297
# Couldn't match ISRC: GBAYE0302298
# Couldn't match ISRC: GBAYE0302299
# Couldn't match ISRC: GBAYE0302300
# Couldn't match ISRC: GBAYE0302301
# Couldn't match ISRC: GBAYE0302303
# Couldn't match ISRC: GBAYE0302302
# Couldn't match ISRC: GBAYE0302304
# Couldn't match ISRC: GBAYE0302305
# Couldn't match ISRC: USIR19915163
# Couldn't match ISRC: USIR19915169
# Couldn't match ISRC: USIR19915170
# Couldn't match ISRC: GBAYE0000920
# Couldn't match ISRC: GBAYE0600333
# Couldn't match ISRC: GBAYE0600344
# Couldn't match ISRC: GBAYE6300121
# Couldn't match ISRC: GBAYE0000921
# Couldn't match ISRC: GBAYE6300408
# Couldn't match ISRC: GBAYE0000922
# Couldn't match ISRC: GBAYE0401867
# Couldn't match ISRC: GBAYE0401912
# Couldn't match ISRC: GBAYE6300412
# Couldn't match ISRC: GBAYE0000923
# Couldn't match ISRC: GBAYE6300154
# Couldn't match ISRC: GBAYE0000924
# Couldn't match ISRC: GBAYE0000925
# Couldn't match ISRC: GBAYE0000926
# Couldn't match ISRC: GBAYE6400569
# Couldn't match ISRC: GBAYE0000927
# Couldn't match ISRC: GBAYE0000928
# Couldn't match ISRC: GBAYE0000929
# Couldn't match ISRC: GBAYE0000930
# Couldn't match ISRC: GBAYE0000931
# Couldn't match ISRC: GBAYE0000932
# Couldn't match ISRC: GBAYE0000933
# Couldn't match ISRC: GBAYE6600499
# Couldn't match ISRC: GBAYE0000934
# Couldn't match ISRC: GBAYE6600041
# Couldn't match ISRC: GBAYE0000935
# Couldn't match ISRC: GBAYE0000936
# Couldn't match ISRC: GBAYE0000937
# Couldn't match ISRC: GBAYE6700001
# Couldn't match ISRC: GBAYE0000938
# Couldn't match ISRC: GBAYE6700026
# Couldn't match ISRC: GBAYE0000939
# Couldn't match ISRC: GBAYE6800009
# Couldn't match ISRC: GBAYE0000940
# Couldn't match ISRC: GBAYE6800011
# Couldn't match ISRC: GBAYE0000941
# Couldn't match ISRC: GBAYE7000511
# Couldn't match ISRC: GBAYE0000942
# Couldn't match ISRC: GBAYE6900033
# Couldn't match ISRC: GBAYE0000943
# Couldn't match ISRC: GBAYE0000944
# Couldn't match ISRC: GBAYE0000945
# Couldn't match ISRC: GBAYE0000946
# Couldn't match ISRC: GBAMC0300001
# Couldn't match ISRC: GBAMC0300002
# Couldn't match ISRC: GBAMC0300003
# Couldn't match ISRC: GBAMC0300004
# Couldn't match ISRC: GBAMC0300005
# Couldn't match ISRC: GBAMC0300006
# Couldn't match ISRC: GBAMC0300007
# Couldn't match ISRC: GBAMC0300008
# Couldn't match ISRC: GBAMC0300009
# Couldn't match ISRC: GBAMC0300010
# Couldn't match ISRC: GBAMC0300011
# Couldn't match ISRC: GBDXG0600127
# Couldn't match ISRC: GBCBR1100174
# Couldn't match ISRC: GBCBR1100178
# Couldn't match ISRC: GBDXG0600089
# Couldn't match ISRC: GBDXG1400056
# Couldn't match ISRC: GBDXG0000111
# Couldn't match ISRC: GBDXG0600064
# Couldn't match ISRC: GBAYE1800753
# Couldn't match ISRC: GBDXG0600007
# Couldn't match ISRC: GBDXG0600057
# Couldn't match ISRC: GBAYE7000113
# Couldn't match ISRC: GBAYE7000283
# Couldn't match ISRC: GBDXG0600061
# Couldn't match ISRC: GBDXG0600075
# Couldn't match ISRC: GBDXG0600129
# Couldn't match ISRC: USWB10103609
# Couldn't match ISRC: GBDXG0600088
# Couldn't match ISRC: USWB10201717
# Couldn't match ISRC: GBDXG0600051
# Couldn't match ISRC: GBDXG0600058
# Couldn't match ISRC: GBDXG0600014
# Couldn't match ISRC: GBDXG0600005
# Couldn't match ISRC: USWB10100695
# Couldn't match ISRC: GBDXG0600062
# Couldn't match ISRC: GBDXG0600008
# Couldn't match ISRC: USWB11101668
# Couldn't match ISRC: GBDXG0600221
# Couldn't match ISRC: USWB10201246
# Couldn't match ISRC: USWB11102048
# Couldn't match ISRC: GBDXG0600146
# Couldn't match ISRC: USWB11101654
# Couldn't match ISRC: GBAYE7200258
# Couldn't match ISRC: GBDXG0000595
# Couldn't match ISRC: USWB11101657
# Couldn't match ISRC: USWB11101656
# Couldn't match ISRC: USWB11101659
# Couldn't match ISRC: CDDXG0400004
# Couldn't match ISRC: GBDXG0400004
# Couldn't match ISRC: USWB10201247
# Couldn't match ISRC: GBDXG0800007
# Couldn't match ISRC: GBDXG0800002
# Couldn't match ISRC: GBDXG1000029
# Couldn't match ISRC: GBDXG1000027
# Couldn't match ISRC: USMR18489034
# Couldn't match ISRC: USA278400050
# Couldn't match ISRC: USAJE0501232
# Couldn't match ISRC: GBDXG0600127
# Couldn't match ISRC: GBDXG0600089
# Couldn't match ISRC: GBAYE7000113
# Couldn't match ISRC: GBAYE7000283
# Couldn't match ISRC: GBDXG0600061
# Couldn't match ISRC: GBDXG0600075
# Couldn't match ISRC: GBDXG0600129
# Couldn't match ISRC: USWB10103609
# Couldn't match ISRC: USWB10103610
# Couldn't match ISRC: GBDXG0600057
# Couldn't match ISRC: GBDXG0600051
# Couldn't match ISRC: GBDXG0600058
# Couldn't match ISRC: GBDXG0600146
# Couldn't match ISRC: USWB11101654
# Couldn't match ISRC: GBAYE7200258
# Couldn't match ISRC: GBDXG0000595
# Couldn't match ISRC: USWB11101657
# Couldn't match ISRC: USWB11101659
# Couldn't match ISRC: GBDXG0800007
# Couldn't match ISRC: USMR18489034
# Couldn't match ISRC: USGF19700914
# Couldn't match ISRC: USMV20000167
# Couldn't match ISRC: USWB11201114
# Couldn't match ISRC: DEN129900321
# Couldn't match ISRC: GBAHT1500246
# Couldn't match ISRC: USWB10403341
# Couldn't match ISRC: USMV20000167
# Couldn't match ISRC: USVI29800019
# Couldn't match ISRC: USWB10300111
# Couldn't match ISRC: USWB10300114
# Couldn't match ISRC: USWB10300118
# Couldn't match ISRC: USWB10300121
# Couldn't match ISRC: USQX91302217
# Couldn't match ISRC: USQX91302219
# Couldn't match ISRC: USSM10500215
# Couldn't match ISRC: USSM10500209
# Couldn't match ISRC: GBAKW0300025
# Couldn't match ISRC: USSM10010823
# Couldn't match ISRC: USSM10010824
# Couldn't match ISRC: QM9AA1571409
# Couldn't match ISRC: QM9AA1571410
# Couldn't match ISRC: QM9AA1571411
# Couldn't match ISRC: QM9AA1571412
# Couldn't match ISRC: QM9AA1571413
# Couldn't match ISRC: QM9AA1571414
# Couldn't match ISRC: QM9AA1571415
# Couldn't match ISRC: QM9AA1571416
# Couldn't match ISRC: QM9AA1571417
# Couldn't match ISRC: QM9AA1571418
# Couldn't match ISRC: QM9AA1571419
# Couldn't match ISRC: QM9AA1571420
# Couldn't match ISRC: QM9AA1571421
# Couldn't match ISRC: QM9AA1571422
# Couldn't match ISRC: QM9AA1571423
# Couldn't match ISRC: QM9AA1571429
# Couldn't match ISRC: QM9AA1571430
# Couldn't match ISRC: QM9AA1571431
# Couldn't match ISRC: QM9AA1571432
# Couldn't match ISRC: QM9AA1571433
# Couldn't match ISRC: QM9AA1571434
# Couldn't match ISRC: QM9AA1571442
# Couldn't match ISRC: QM9AA1571443
# Couldn't match ISRC: QM9AA1571444
# Couldn't match ISRC: QM9AA1571445
# Couldn't match ISRC: QM9AA1571446
# Couldn't match ISRC: QM9AA1571447
# Couldn't match ISRC: QM9AA1571448
# Couldn't match ISRC: QM9AA1571449
# Couldn't match ISRC: QM9AA1571450
# Couldn't match ISRC: QM9AA1571451
# Couldn't match ISRC: QM9AA1571452
# Couldn't match ISRC: QM9AA1571453
# Couldn't match ISRC: USSM10311975
# Couldn't match ISRC: USIR10312567
# Couldn't match ISRC: USEE10240729
# Couldn't match ISRC: USRC10202315
# Couldn't match ISRC: USAM10300193
# Couldn't match ISRC: SEAYD7315160
# Couldn't match ISRC: SEAYD7390001
# Couldn't match ISRC: SEA017225010
# Couldn't match ISRC: DEAYD7313070
# Couldn't match ISRC: SEAYD7880006
# Couldn't match ISRC: SEUV71000394
# Couldn't match ISRC: SEAYD7890002
# Couldn't match ISRC: USAT20302754
# Couldn't match ISRC: SEAYD7690004
# Couldn't match ISRC: SEUV71000390
# Couldn't match ISRC: USAT20302166
# Couldn't match ISRC: USAT20903514
# Couldn't match ISRC: SEAYD7503010
# Couldn't match ISRC: SEAYD7602071
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\urllib3\connectionpool.py:868, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     867 try:
# --> 868     retries = retries.increment(method, url, response=response, _pool=self)
#     869 except MaxRetryError:
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=6HJ6A7irb5VBy33Hqa0fhd (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\spotipy\client.py:264, in Spotify._internal_call(self, method, url, payload, params)
#     263 try:
# --> 264     response = self._session.request(
#     265         method, url, headers=headers, proxies=self.proxies,
#     266         timeout=self.requests_timeout, **args
#     267     )
#     269     response.raise_for_status()
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\requests\adapters.py:556, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     555 if isinstance(e.reason, ResponseError):
# --> 556     raise RetryError(e, request=request)
#     558 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=6HJ6A7irb5VBy33Hqa0fhd (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# c:\Users\User\Documents\R_Work\research\music_data\code\data_creation\spotify_access_isrc_only_acoustic_features.ipynb Cell 32 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/R_Work/research/music_data/code/data_creation/spotify_access_isrc_only_acoustic_features.ipynb#X40sZmlsZQ%3D%3D?line=10'>11</a> time.sleep(1)  # Slow down to 4 requests per second
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/R_Work/research/music_data/code/data_creation/spotify_access_isrc_only_acoustic_features.ipynb#X40sZmlsZQ%3D%3D?line=11'>12</a> return sp.audio_features(spotify_id)[0]
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\spotipy\client.py:1732, in Spotify.audio_features(self, tracks)
#    1731     trackid = self._get_id("track", tracks)
# -> 1732     results = self._get("audio-features/?ids=" + trackid)
#    1733 else:
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\spotipy\client.py:321, in Spotify._get(self, url, args, payload, **kwargs)
#     319     kwargs.update(args)
# --> 321 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\spotipy\client.py:305, in Spotify._internal_call(self, method, url, payload, params)
#     304         reason = None
# --> 305     raise SpotifyException(
#     306         429,
#     307         -1,
#     308         "%s:\n %s" % (request.path_url, "Max Retries"),
#     309         reason=reason
#     310     )
#     311 except ValueError:
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=6HJ6A7irb5VBy33Hqa0fhd:
#  Max Retries, reason: too many 429 error responses
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# c:\Users\User\Documents\R_Work\research\music_data\code\data_creation\spotify_access_isrc_only_acoustic_features.ipynb Cell 32 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/R_Work/research/music_data/code/data_creation/spotify_access_isrc_only_acoustic_features.ipynb#X40sZmlsZQ%3D%3D?line=11'>12</a> track = results['tracks']['items'][0]
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/R_Work/research/music_data/code/data_creation/spotify_access_isrc_only_acoustic_features.ipynb#X40sZmlsZQ%3D%3D?line=13'>14</a> # Fetch audio features using Spotify ID
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/R_Work/research/music_data/code/data_creation/spotify_access_isrc_only_acoustic_features.ipynb#X40sZmlsZQ%3D%3D?line=14'>15</a> audio_features = fetch_audio_features(track["id"])
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/R_Work/research/music_data/code/data_creation/spotify_access_isrc_only_acoustic_features.ipynb#X40sZmlsZQ%3D%3D?line=16'>17</a> # Extract and append only the acoustic features and ISRC to data_to_append
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/R_Work/research/music_data/code/data_creation/spotify_access_isrc_only_acoustic_features.ipynb#X40sZmlsZQ%3D%3D?line=17'>18</a> if audio_features is not None:
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File c:\Users\User\anaconda3\envs\new_music_data\lib\site-packages\tenacity\__init__.py:326, in BaseRetrying.iter(self, retry_state)
#     324     if self.reraise:
#     325         raise retry_exc.reraise()
# --> 326     raise retry_exc from fut.exception()
#     328 if self.wait:
#     329     sleep = self.wait(retry_state)
#
# RetryError: RetryError[<Future at 0x2433db68a90 state=finished raised SpotifyException>]

# %% [markdown]
# # First random sample of songs - without ISRC
# To do:
# - move this into a new Jupyter notebook

# %%
import os
import spotipy # lightweight Python library for the Spotify Web API
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials # to access authorised Spotify data

# %%
# package for accessing the local environment variables
import os

# get the client id and client secret from the environment variables
client_id = os.environ.get('SPOTIPY_CLIENT_ID')
client_secret = os.environ.get('SPOTIPY_CLIENT_SECRET')

if not client_id or not client_secret:
    raise ValueError("Spotify API credentials not found in environment variables")

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
#required package

from pandas import read_csv

# loading in the csv file with the songs from billboard and musicbrainz

df_HH_mb_matched = read_csv('C:/R work/Research/music_data/data/interim_data/df_hh_and_mb_leftjoin_fuzzy.csv')

# %%
# draw a random observation from the dataframe, retaining only the first two columns 
random_100_df = df_HH_mb_matched.sample(100)[['Artist', 'Track']]

# %%
#create the song infor retreival function

# added a bit to the function to handle errors and retries
import time

#here the max retries is 3
def get_song_data(song_name, artist_name, max_retries=3):
    query = f'track:{song_name} artist:{artist_name}'
    retries = 0
    
    #while loop to retry the query if it fails n times (as defined by max_retries)
    while retries <= max_retries:
        try:
            results = sp.search(q=query, type='track', limit=1)
            
            if results['tracks']['items']:
                track = results['tracks']['items'][0]

               # Get the track's ID
                track_id = track['id']
                
                # Get the audio features for the track
                audio_features = sp.audio_features([track_id])[0]

                song_data = {
                    'song_name': track['name'],
                    'artist_name': track['artists'][0]['name'],
                    'album_name_spotify': track['album']['name'],
                    'release_date_spotify': track['album']['release_date'],
                    'popularity': track['popularity'],
                    'explicit': track['explicit'],
                    'duration_ms': track['duration_ms'],
                    # 'preview_url': track['preview_url'],
                    'acousticness': audio_features['acousticness'],
                    'danceability': audio_features['danceability'],
                    'energy': audio_features['energy'],
                    'instrumentalness': audio_features['instrumentalness'],
                    'liveness': audio_features['liveness'],
                    'loudness': audio_features['loudness'],
                    'speechiness': audio_features['speechiness'],
                    'valence': audio_features['valence'],
                    'tempo': audio_features['tempo'],
                    'key': audio_features['key'],
                    'mode': audio_features['mode'], # mode is either major or minor
                    'time_signature': audio_features['time_signature']
                }
                return song_data
            else:
                return None
        
        except Exception as e:
            print(f"Error: {e}")
            retries += 1
            sleep_time = 2 ** retries
            print(f"Retrying ({retries}/{max_retries}) after {sleep_time} seconds")
            time.sleep(sleep_time)
    
    return None

# %%
# create an empty dataframe
results_df = pd.DataFrame(columns=["Track", "Artist", "song_name", "artist_name", "album_name_spotify", "release_date_spotify",
                                    "popularity", "explicit", "duration_ms", "acousticness", "danceability","energy","instrumentalness",
                                    "liveness", "loudness", "speechiness", "valence", "tempo", "key", "mode", "time_signature"])

# loop over the random sample dataframe

rest_period = 0.2  # Time in seconds between requests

for index, row in random_100_df.iterrows():
    song_name = row["Track"]
    artist_name = row["Artist"]

    song_data = get_song_data(song_name, artist_name)
    if song_data:
        song_data["Track"] = song_name
        song_data["Artist"] = artist_name

        # Convert song_data dictionary to a DataFrame
        song_data_df = pd.DataFrame([song_data])

        # changed results.append to results_df.concat as per the errors in the previous code
        
        results_df = pd.concat([results_df, song_data_df], ignore_index=True)
    else:
        print(f"Song not found: {song_name} by {artist_name}")
        
    time.sleep(rest_period)  # Pause execution for the specified rest period
# Out:
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Karma by Lloyd Banks Featuring Avant
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Area Codes by Ludacris Featuring Nate Dogg
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: If I Could Go! by Angie Martinez Featuring Lil' Mo & Sacario
# Song not found: Hey Luv (Anything) by Mobb Deep Featuring 112
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Sympathy For The Devil (Remixes) by The Rolling Stones
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Don't Think I'm Not by Kandi
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Don't Think I'm Not by Kandi
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Ride Wit Me by Nelly Featuring City Spud
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Untitled (How Does It Feel) by D'Angelo
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: What Happened To That Boy by Baby Featuring Clipse
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Move Ya Body by Nina Sky Featuring Jabba
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Gangsta Lovin' by Eve Featuring Alicia Keys
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Drift Away by Uncle Kracker Featuring Dobie Gray
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Feel It Boy by Beenie Man Featuring Janet
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Oochie Wally by QB Finest Featuring Nas & Bravehearts
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: I'm Your Angel by R. Kelly & Celine Dion
# C:\Users\astaub\AppData\Local\Temp\ipykernel_16592\1066911844.py:24: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   results_df = pd.concat([results_df, song_data_df], ignore_index=True)
# Song not found: Work It by Missy "Misdemeanor" Elliott
