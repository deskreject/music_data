# %% [markdown]
# 	# Author: Alexander Staub
# 	## Last changed: 2025.02.13
# 	## Purpose: Getting the chartmetrics IDs for a list of songs

# %%
#installing packages
import time
import requests
import logging
import pandas as pd
from pprint import pprint
from datetime import datetime
import json
import os
import numpy as np

# %% [markdown]
# # CHANGE ACCORDING TO WORKER

# %%
# ================== WORKER-SPECIFIC CONFIGURATION ==================
# --- CHANGE: This is the ONLY line you will edit in each copied worker notebook. ---
PART_NUMBER = 1  # For worker 1, set to 1. For worker 2, set to 2, etc.
# ===================================================================

# %%
#Setup the logging of the errors
# --- IMPORTANT --- change to the correct worker number
logging.basicConfig(
    filename=f'chartmetric_api_metadata_worker_{PART_NUMBER}.log',
    level=logging.INFO,
    format='%(asctime)s %(levelname)s: %(message)s'
)

# %%
# Define API host and your refresh token
HOST = 'https://api.chartmetric.com'
with open("chartmetric_refresh_token.txt", "r") as f:
    REFRESH_TOKEN = f.read().strip()

# %%
# Retrieve an access token using the refresh token
token_response = requests.post(f'{HOST}/api/token', json={'refreshtoken': REFRESH_TOKEN})

# Check if the token was retrieved successfully
if token_response.status_code != 200:

    # Log the error and raise an exception
    logging.error(f"Token retrieval error: {token_response.status_code}")
    raise Exception(f"Error: received {token_response.status_code} from /api/token")

# Extract the access token from the response
access_token = token_response.json()['token']

# Define the headers for the API requests
headers = {'Authorization': f'Bearer {access_token}'}

# %% [markdown]
# # Defining the get_request
#
# Robust request logic that:
# - backs off for a max of 26 hours in retries
# - logs all erros it encounters

# %%
# --- Robust get_request Function ---
def get_request(endpoint, params=None, max_retries=5):
    backoff = 1  # initial backoff in seconds (used if header data is missing)
    for attempt in range(max_retries):
        try:
            response = requests.get(f"{HOST}{endpoint}", headers=headers, params=params)
        except Exception as ex:
            logging.error(f"Network error on attempt {attempt+1} for {endpoint}: {ex}")
            time.sleep(backoff)
            backoff *= 2
            continue

# Log the response status code and rate limit headers
        logging.info(f"Request to {endpoint} returned {response.status_code}. RateLimit headers: {response.headers}")

# Check if the response status code is 200
        if response.status_code == 200:
            return response.json()

# Handle different types of errors
# 401: Token may have expired; refresh it
        elif response.status_code == 401:
            # Token may have expired; refresh it
            logging.warning(f"401 error for {endpoint}. Refreshing token.")
            token_response = requests.post(f'{HOST}/api/token', json={'refreshtoken': REFRESH_TOKEN})
            if token_response.status_code != 200:
                logging.error(f"Token refresh failed: {token_response.status_code}")
                raise Exception(f"Token refresh failed with status {token_response.status_code}")
            new_token = token_response.json()['token']
            headers['Authorization'] = f'Bearer {new_token}'
            time.sleep(backoff)
            backoff *= 2

# 429: Rate limit exceeded; wait and retry
        elif response.status_code == 429:
            # Rate limit exceeded.
            reset_timestamp = response.headers.get("X-RateLimit-Reset")
            if reset_timestamp:
                # Wait until the time provided by the API
                sleep_time = int(reset_timestamp) - int(time.time())
                if sleep_time < 0:
                    sleep_time = backoff
            else:
                # No wait time provided by the API; compute one that totals 26 hours over all retries.
                total_wait_limit = 26 * 3600  # total wait time in seconds (26 hours)
                # Sum exponential weights for remaining attempts: for i from current attempt to max_retries-1
                remaining_weights = sum(2 ** i for i in range(attempt, max_retries))
                # Use the weight for the current attempt to assign a fraction of the total wait.
                sleep_time = total_wait_limit * (2 ** attempt / remaining_weights)
            logging.warning(f"429 error for {endpoint}. Sleeping for {sleep_time} seconds (attempt {attempt+1}/{max_retries}).")
            time.sleep(sleep_time)
            backoff *= 2

# 500: Server error; wait and retry
        elif response.status_code >= 500:
            logging.warning(f"Server error {response.status_code} for {endpoint}. Retrying after {backoff} seconds.")
            time.sleep(backoff)
            backoff *= 2

        else:
            logging.error(f"Error {response.status_code} for {endpoint}: {response.text}")
            raise Exception(f"Error: received {response.status_code} from {endpoint}")

# If the loop completes without returning, raise an exception
    raise Exception(f"Max retries exceeded for endpoint {endpoint}")

# %% [markdown]
# # CHANGE ACCORDING TO WORKER

# %%
# --- Cell 7: WORKER CONFIGURATION AND EXECUTION ---


# --- CHANGE: Dynamic rate limit calculation ---
TOTAL_RATE_LIMIT = 3.5
NUM_WORKERS = 3  # Must match the controller script
# Each worker gets an equal share of the rate limit.
TIME_PER_REQUEST = 1 / (TOTAL_RATE_LIMIT / NUM_WORKERS) 
### WHAT THIS CHANGE DOES:
# This is the most important change for avoiding rate limits. It ensures that the sum of all
# workers' requests does not exceed your total allowance.

checkpoint_interval = 1000  # How often to save progress (e.g., every 1000 records)

# Dynamic file path generation ---
WORKER_INPUT_DIR = "//bigdata.wu.ac.at/delpero/Data_alexander/data/incidental/chartmetric/worker_inputs_chartmetric_ids/"
ID_OUTPUT_DIR = "//bigdata.wu.ac.at/delpero/Data_alexander/data/raw_data/chartmetric/chartmetric_ids/"

INPUT_FILE = os.path.join(WORKER_INPUT_DIR, f"ids_part_{PART_NUMBER}.csv")
# Each worker gets its own output directory to prevent file conflicts
CHECKPOINT_DIR = os.path.join(ID_OUTPUT_DIR, f"part_{PART_NUMBER}") 
CHECKPOINT_FILE = os.path.join(CHECKPOINT_DIR, "chartmetric_ids_checkpoint.csv")

### WHAT THIS CHANGE DOES:
# This makes the script a reusable template. By changing only PART_NUMBER at the top,
# the script automatically targets the correct input file (e.g., `ids_part_1.csv`)
# and creates a unique, safe output directory (e.g., `.../part_1/`) for its checkpoints.

os.makedirs(CHECKPOINT_DIR, exist_ok=True)


# --- CHANGE: Load worker-specific data ---
print(f"WORKER {PART_NUMBER}: Loading data from {INPUT_FILE}")
worker_df = pd.read_csv(INPUT_FILE)

# --- ADD THIS LINE TO REMOVE BAD DATA ---
worker_df.dropna(subset=['spotify_isrc'], inplace=True)

# %%
# --- Function to Retrieve Chartmetric ID for an ISRC ---
def get_chartmetric_ids(isrc):
    endpoint = f"/api/track/isrc/{isrc}/get-ids"
    try:
        response = get_request(endpoint)
    
    # Log the response status code and rate limit headers
    except Exception as e:
        logging.error(f"Failed to get Chartmetric ID for ISRC {isrc}: {e}")
        return None

    # Expecting response["obj"] to be a non-empty list
    if response.get("obj") and isinstance(response["obj"], list) and len(response["obj"]) > 0:

        # Extract the chartmetric_ids from the first element of the list
        cm_ids = response["obj"][0].get("chartmetric_ids", None)

        # Check if cm_ids is a non-empty list
        if cm_ids and isinstance(cm_ids, list) and len(cm_ids) > 0:
            try:
                return float(cm_ids[0])
            
            # Log conversion errors
            except Exception as conv_err:
                logging.error(f"Conversion error for ISRC {isrc}: {conv_err}")
                return None
    return None

# %%
print("--- Initializing Main Processing Loop ---")

# A temporary list to hold new results before writing to file
results_buffer = []

try:
    # --- STEP 2a: Load the set of already processed ISRCs for fast lookups ---
    # This is the "resume" part. We check the checkpoint file to see what's already done.
    processed_isrcs = set()
    if os.path.exists(CHECKPOINT_FILE):
        print(f"Checkpoint file found. Loading processed ISRCs from: {CHECKPOINT_FILE}")
        logging.info(f"Loading processed ISRCs from checkpoint: {CHECKPOINT_FILE}")
        try:
            # We only need the 'spotify_isrc' column to know what's already done.
            processed_df = pd.read_csv(CHECKPOINT_FILE, usecols=['spotify_isrc'])
            processed_isrcs = set(processed_df['spotify_isrc'].dropna().unique())
            print(f"Loaded {len(processed_isrcs):,} previously completed ISRCs. They will be skipped.")
            logging.info(f"Loaded {len(processed_isrcs):,} previously completed ISRCs.")
        except (pd.errors.EmptyDataError, KeyError, FileNotFoundError):
            print("Checkpoint file is empty or invalid. A new one will be created.")
            logging.warning("Checkpoint file was found but is empty or invalid.")
            # If the file is broken, we start fresh and create the header.
            pd.DataFrame(columns=['spotify_isrc', 'chartmetric_ids']).to_csv(CHECKPOINT_FILE, index=False)
    else:
        print("No checkpoint file found. Creating a new one with headers.")
        logging.info("No checkpoint file found. Creating a new one.")
        # If the file doesn't exist, create it with the necessary columns.
        pd.DataFrame(columns=['spotify_isrc', 'chartmetric_ids']).to_csv(CHECKPOINT_FILE, index=False)

    
    
    # --- STEP 2: Iterate through the main dataframe ---
    total_rows = len(worker_df)
    print(f"Beginning iteration over {total_rows} total rows.")
    
    for idx, row in worker_df.iterrows():
        isrc = row['spotify_isrc']
        
        # --- EFFICIENT RESUME LOGIC ---
        # If we have already processed this ISRC in a previous run, skip it immediately.
        if isrc in processed_isrcs:
            continue

        loop_start_time = time.time()
        print(f"Processing row {idx}/{total_rows}: ISRC = {isrc}")

        try:
            chartmetric_id = get_chartmetric_ids(isrc)
        except Exception as e:
            print(f"Error processing ISRC {isrc} at row {idx}: {e}")
            logging.error(f"Error processing ISRC {isrc} at row {idx}: {e}")
            chartmetric_id = None
        
        # Add the new result to our temporary buffer instead of the giant dataframe
        results_buffer.append({
            'spotify_isrc': isrc, 
            'chartmetric_ids': chartmetric_id
        })
        
        # Add to our in-memory set to avoid re-processing in the *same* run if there are duplicates
        processed_isrcs.add(isrc)
        
        logging.info(f"Buffered ISRC {isrc}: Chartmetric ID = {chartmetric_id}")

        # --- DYNAMIC SLEEP LOGIC ---
        elapsed_time = time.time() - loop_start_time
        sleep_duration = TIME_PER_REQUEST - elapsed_time
        if sleep_duration > 0:
            time.sleep(sleep_duration)
        
        # --- FAST APPEND-BASED CHECKPOINT ---
        # When the buffer is full, append it to the checkpoint file. This is very fast.
        if len(results_buffer) >= checkpoint_interval:
            print(f"--- Checkpoint interval reached. Appending {len(results_buffer)} new results... ---")
            checkpoint_df = pd.DataFrame(results_buffer)
            # Use mode='a' (append) and header=False to efficiently add to the existing file
            checkpoint_df.to_csv(CHECKPOINT_FILE, mode='a', header=False, index=False)
            results_buffer = [] # Reset the buffer for the next batch
            print(f"--- Batch appended to checkpoint file. ---")
            logging.info(f"Appended {len(checkpoint_df)} rows to checkpoint.")

finally:
    # --- FINAL SAVE OF REMAINING RESULTS ---
    # This ensures that even if the loop is interrupted, the last batch of results is saved.
    if results_buffer:
        print(f"\nLoop finished or was interrupted. Appending {len(results_buffer)} final results...")
        final_df = pd.DataFrame(results_buffer)
        final_df.to_csv(CHECKPOINT_FILE, mode='a', header=False, index=False)
        print(f"Final batch appended to: {CHECKPOINT_FILE}")
        logging.info(f"Appended {len(final_df)} final rows to checkpoint.")
    
    print("\nProcessing complete.")
    logging.info("All processing is complete.")
# Out:
# --- Initializing Main Processing Loop ---
# No checkpoint file found. Creating a new one with headers.
# Beginning iteration over 3169134 total rows.
# Processing row 0/3169134: ISRC = GBARL0100013
# Processing row 1/3169134: ISRC = GBARL0100173
# Processing row 2/3169134: ISRC = FR2X41547576
# Processing row 3/3169134: ISRC = ARA340800036
# Processing row 4/3169134: ISRC = BEY900700058
# Processing row 5/3169134: ISRC = BEQ028000010
# Processing row 6/3169134: ISRC = BEZ050000047
# Processing row 7/3169134: ISRC = NLA307200010
# Processing row 8/3169134: ISRC = BEK011900408
# Processing row 9/3169134: ISRC = BED010200806
# Processing row 10/3169134: ISRC = BEC010100040
# Processing row 11/3169134: ISRC = BEY900900138
# Processing row 12/3169134: ISRC = GBAKW0100229
# Processing row 13/3169134: ISRC = NLA910160001
# Processing row 14/3169134: ISRC = FRO060200490
# Processing row 15/3169134: ISRC = DEN060200635
# Processing row 16/3169134: ISRC = BEY301200423
# Processing row 17/3169134: ISRC = USVT10100031
# Processing row 18/3169134: ISRC = DEAF71252772
# Processing row 19/3169134: ISRC = ITA810100258
# Processing row 20/3169134: ISRC = NL4VT2100105
# Processing row 21/3169134: ISRC = BEF010324000
# Processing row 22/3169134: ISRC = BEZ050200031
# Processing row 23/3169134: ISRC = NLA306600126
# Processing row 24/3169134: ISRC = BEUM71400276
# Processing row 25/3169134: ISRC = NLA306600011
# Processing row 26/3169134: ISRC = USDHM1709417
# Processing row 27/3169134: ISRC = BEK011900417
# Processing row 28/3169134: ISRC = BED010300868
# Processing row 29/3169134: ISRC = GBBBM0202096
# Processing row 30/3169134: ISRC = USAT22400662
# Processing row 31/3169134: ISRC = FRZLS0200020
# Processing row 32/3169134: ISRC = QM4TW1601447
# Processing row 33/3169134: ISRC = GBBDM0300023
# Processing row 34/3169134: ISRC = GBAWV0203082
# Processing row 35/3169134: ISRC = GBAAP0200657
# Processing row 36/3169134: ISRC = BEK011491150
# Processing row 37/3169134: ISRC = BE4MJ2200021
# Processing row 38/3169134: ISRC = USXTN1042759
# Processing row 39/3169134: ISRC = NLF711303005
# Processing row 40/3169134: ISRC = NLC050201463
# Processing row 41/3169134: ISRC = NLC050201464
# Processing row 42/3169134: ISRC = NLS241101082
# Processing row 43/3169134: ISRC = NLC050201466
# Processing row 44/3169134: ISRC = NLC050201467
# Processing row 45/3169134: ISRC = NLC050201470
# Processing row 46/3169134: ISRC = NLC050201471
# Processing row 47/3169134: ISRC = NLC050201472
# Processing row 239/3169134: ISRC = SEVEO1801009
# Processing row 240/3169134: ISRC = ES5088304745
# Processing row 241/3169134: ISRC = ES6060226401
# Processing row 242/3169134: ISRC = ES5087600198
# Processing row 243/3169134: ISRC = ES6060226403
# Processing row 244/3169134: ISRC = ES6060226405
# Processing row 245/3169134: ISRC = ES5087600197
# Processing row 246/3169134: ISRC = ES6060226407
# Processing row 247/3169134: ISRC = ES6060226408
# Processing row 248/3169134: ISRC = ES6060226409
# Processing row 249/3169134: ISRC = ES5087600201
# Processing row 250/3169134: ISRC = ES6060226411
# Processing row 251/3169134: ISRC = ES5087600203
# Processing row 252/3169134: ISRC = ES5087600204
# Processing row 253/3169134: ISRC = ES6060226414
# Processing row 254/3169134: ISRC = ES5151701488
# Processing row 255/3169134: ISRC = NLGZ20903001
# Processing row 256/3169134: ISRC = NLGZ20903002
# Processing row 257/3169134: ISRC = NLGZ20903003
# Processing row 258/3169134: ISRC = US2W61540101
# Processing row 259/3169134: ISRC = NLGZ20903005
# Processing row 260/3169134: ISRC = NLGZ20903006
# Processing row 261/3169134: ISRC = NLGZ20903007
# Processing row 262/3169134: ISRC = ES37A0710801
# Processing row 263/3169134: ISRC = USSM10105639
# Processing row 264/3169134: ISRC = GBCNR8500002
# Processing row 265/3169134: ISRC = USRC18404638
# Processing row 266/3169134: ISRC = GB01A0600358
# Processing row 267/3169134: ISRC = USMO18400528
# Processing row 268/3169134: ISRC = USMC14401469
# Processing row 269/3169134: ISRC = DEBL60496413
# Processing row 270/3169134: ISRC = USBB10100242
# Processing row 271/3169134: ISRC = USA370574053
# Processing row 272/3169134: ISRC = USMC14573006
# Processing row 273/3169134: ISRC = USA370574055
# Processing row 274/3169134: ISRC = USMC15048886
# Processing row 275/3169134: ISRC = DEUE22381768
# Processing row 276/3169134: ISRC = GBHQC0502800
# Processing row 277/3169134: ISRC = BGA671180705
# Processing row 278/3169134: ISRC = USMC13924403
# Processing row 279/3169134: ISRC = DEG931050403
# Processing row 280/3169134: ISRC = DEG931050404
# Processing row 281/3169134: ISRC = DEG931050405
# Processing row 282/3169134: ISRC = USSM18900396
# Processing row 283/3169134: ISRC = USLIC0601897
# Processing row 284/3169134: ISRC = GB-SMU-38-97646
# Processing row 285/3169134: ISRC = GB-SMU-38-97648
# Processing row 286/3169134: ISRC = USSM11206595
# Processing row 287/3169134: ISRC = USSM10109748
# Processing row 288/3169134: ISRC = USVI21100150
# Processing row 289/3169134: ISRC = USVI21100147
# Processing row 290/3169134: ISRC = USVI21100148
# Processing row 291/3169134: ISRC = USVI21100151
# Processing row 292/3169134: ISRC = USVI21100135
# Processing row 293/3169134: ISRC = USVI21100149
# Processing row 294/3169134: ISRC = USVI21100153
# Processing row 295/3169134: ISRC = USVI21100155
# Processing row 296/3169134: ISRC = USVI21100136
# Processing row 297/3169134: ISRC = USVI21100146
# Processing row 298/3169134: ISRC = USVI21100158
# Processing row 299/3169134: ISRC = USVI21200762
# Processing row 300/3169134: ISRC = GBCAD0101454
# Processing row 301/3169134: ISRC = USVI21100156
# Processing row 302/3169134: ISRC = FRX290102120
# Processing row 303/3169134: ISRC = GBCQV1600731
# Processing row 304/3169134: ISRC = GBCQV1600732
# Processing row 305/3169134: ISRC = GBCQV1600733
# Processing row 306/3169134: ISRC = GBCQV1600734
# Processing row 307/3169134: ISRC = GBCQV1600735
# Processing row 308/3169134: ISRC = GBCQV1600736
# Processing row 309/3169134: ISRC = GBCQV1600737
# Processing row 310/3169134: ISRC = GBCQV1600738
# Processing row 311/3169134: ISRC = GBCQV1600739
# Processing row 312/3169134: ISRC = GBCQV1600740
# Processing row 313/3169134: ISRC = GBCQV1600741
# Processing row 314/3169134: ISRC = GBCQV1600742
# Processing row 315/3169134: ISRC = ATK239300219
# Processing row 316/3169134: ISRC = ATK239300166
# Processing row 317/3169134: ISRC = ATK239000002
# Processing row 318/3169134: ISRC = DEUM72206053
# Processing row 319/3169134: ISRC = ATK239300169
# Processing row 320/3169134: ISRC = ATK239000053
# Processing row 321/3169134: ISRC = ATK239300171
# Processing row 322/3169134: ISRC = DEUM71801398
# Processing row 323/3169134: ISRC = ATK238900009
# Processing row 324/3169134: ISRC = DEUM71801400
# Processing row 325/3169134: ISRC = ATK238700002
# Processing row 326/3169134: ISRC = ATK238900042
# Processing row 327/3169134: ISRC = DEUM71402214
# Processing row 328/3169134: ISRC = ATK239300175
# Processing row 329/3169134: ISRC = ATK239300176
# Processing row 330/3169134: ISRC = ATK239300177
# Processing row 331/3169134: ISRC = FRZ015501530
# Processing row 332/3169134: ISRC = FR8X02300957
# Processing row 333/3169134: ISRC = US38Y2428239
# Processing row 334/3169134: ISRC = FRZ015501540
# Processing row 335/3169134: ISRC = FRZ015600680
# Processing row 336/3169134: ISRC = FRX290302090
# Processing row 337/3169134: ISRC = FRX290302110
# Processing row 338/3169134: ISRC = FRX290302150
# Processing row 339/3169134: ISRC = FRX290302200
# Processing row 340/3169134: ISRC = FRX290302220
# Processing row 341/3169134: ISRC = FRX290302230
# Processing row 342/3169134: ISRC = FRX290302250
# Processing row 343/3169134: ISRC = FRX290301481
# Processing row 344/3169134: ISRC = FRX290301482
# Processing row 345/3169134: ISRC = FRX290301503
# Processing row 346/3169134: ISRC = FRX290301502
# Processing row 347/3169134: ISRC = FRX290301521
# Processing row 348/3169134: ISRC = FRX290301522
# Processing row 349/3169134: ISRC = USSM19921976
# Processing row 350/3169134: ISRC = USSM19921977
# Processing row 351/3169134: ISRC = USSM19921979
# Processing row 352/3169134: ISRC = USSM19921980
# Processing row 353/3169134: ISRC = USSM19921981
# Processing row 354/3169134: ISRC = USSM19921982
# Processing row 355/3169134: ISRC = USSM19921983
# Processing row 356/3169134: ISRC = USSM19921984
# Processing row 357/3169134: ISRC = USSM19921988
# Processing row 358/3169134: ISRC = USSM19921989
# Processing row 359/3169134: ISRC = USSM19921990
# Processing row 360/3169134: ISRC = USSM19921991
# Processing row 361/3169134: ISRC = FRX290500040
# Processing row 362/3169134: ISRC = FRX290500120
# Processing row 363/3169134: ISRC = DER751406302
# Processing row 364/3169134: ISRC = DER751500837
# Processing row 365/3169134: ISRC = DER752092306
# Processing row 366/3169134: ISRC = DEU240653567
# Processing row 367/3169134: ISRC = DEA340701869
# Processing row 368/3169134: ISRC = DER752092309
# Processing row 369/3169134: ISRC = DER412200887
# Processing row 370/3169134: ISRC = DEA610200745
# Processing row 371/3169134: ISRC = DER751641602
# Processing row 372/3169134: ISRC = DER751414001
# Processing row 373/3169134: ISRC = ITB007370501
# Processing row 374/3169134: ISRC = ITB008170527
# Processing row 375/3169134: ISRC = ITB008170528
# Processing row 376/3169134: ISRC = ITB008170529
# Processing row 377/3169134: ISRC = ITB008170531
# Processing row 378/3169134: ISRC = ITB008170532
# Processing row 379/3169134: ISRC = ITB008070596
# Processing row 380/3169134: ISRC = ITB007070546
# Processing row 381/3169134: ISRC = ITB007070538
# Processing row 382/3169134: ISRC = ITB002000006
# Processing row 383/3169134: ISRC = ITB007570517
# Processing row 384/3169134: ISRC = ITB000500873
# Processing row 385/3169134: ISRC = GBBRQ0100041
# Processing row 386/3169134: ISRC = GBBRQ0100032
# Processing row 387/3169134: ISRC = GBBRQ0100039
# Processing row 388/3169134: ISRC = GBBRQ0100031
# Processing row 389/3169134: ISRC = GBBRQ0100040
# Processing row 390/3169134: ISRC = GBBRQ9810016
# Processing row 391/3169134: ISRC = GBBRQ0100030
# Processing row 392/3169134: ISRC = GBBRQ0000096
# Processing row 393/3169134: ISRC = GBBRQ0000014
# Processing row 394/3169134: ISRC = GBBRQ0100068
# Processing row 395/3169134: ISRC = GBBRQ0000007
# Processing row 396/3169134: ISRC = GBBRQ0100053
# Processing row 397/3169134: ISRC = GBBRQ0100008
# Processing row 398/3169134: ISRC = HKI190781107
# Processing row 399/3169134: ISRC = HKI190781108
# Processing row 400/3169134: ISRC = HKI190781109
# Processing row 401/3169134: ISRC = HKI190781110
# Processing row 402/3169134: ISRC = HKI190781111
# Processing row 403/3169134: ISRC = HKI190781112
# Processing row 404/3169134: ISRC = HKI190781113
# Processing row 405/3169134: ISRC = HKI190781114
# Processing row 406/3169134: ISRC = HKI190781115
# Processing row 407/3169134: ISRC = HKI190781116
# Processing row 408/3169134: ISRC = HKI190781117
# Processing row 409/3169134: ISRC = HKI190781118
# Processing row 410/3169134: ISRC = HKI190781119
# Processing row 411/3169134: ISRC = HKI190781120
# Processing row 412/3169134: ISRC = HKI190781121
# Processing row 413/3169134: ISRC = HKI190781122
# Processing row 414/3169134: ISRC = HKI190781124
# Processing row 415/3169134: ISRC = GBF077640101
# Processing row 416/3169134: ISRC = GBF077213380
# Processing row 417/3169134: ISRC = GBF077700154
# Processing row 418/3169134: ISRC = GBF077700155
# Processing row 419/3169134: ISRC = DEF059102341
# Processing row 420/3169134: ISRC = DEB330705601
# Processing row 421/3169134: ISRC = DEB330705602
# Processing row 422/3169134: ISRC = DEB330705604
# Processing row 423/3169134: ISRC = DEB330705605
# Processing row 424/3169134: ISRC = DEB330705606
# Processing row 425/3169134: ISRC = DEB330705607
# Processing row 426/3169134: ISRC = DEB330705608
# Processing row 427/3169134: ISRC = DEB330705609
# Processing row 428/3169134: ISRC = DEB330705610
# Processing row 429/3169134: ISRC = DEB330705611
# Processing row 430/3169134: ISRC = DEB330705612
# Processing row 431/3169134: ISRC = DEB330705613
# Processing row 432/3169134: ISRC = DEB330705614
# Processing row 433/3169134: ISRC = DEB330705615
# Processing row 434/3169134: ISRC = USVZX1103908
# Processing row 435/3169134: ISRC = DEU471815170
# Processing row 436/3169134: ISRC = DEU471815169
# Processing row 437/3169134: ISRC = USCA25700190
# Processing row 438/3169134: ISRC = GBGPQ0800042
# Processing row 439/3169134: ISRC = GBBLY1002683
# Processing row 440/3169134: ISRC = USEM38800216
# Processing row 441/3169134: ISRC = DEU471815354
# Processing row 442/3169134: ISRC = USTE10802701
# Processing row 443/3169134: ISRC = USTE10803701
# Processing row 444/3169134: ISRC = USTE10804701
# Processing row 445/3169134: ISRC = USTE10805701
# Processing row 446/3169134: ISRC = USTE10806701
# Processing row 447/3169134: ISRC = USTE10807701
# Processing row 448/3169134: ISRC = GBAYE0701653
# Processing row 449/3169134: ISRC = USBB14201011
# Processing row 450/3169134: ISRC = GBAYE6100604
# Processing row 451/3169134: ISRC = USBB14000471
# Processing row 452/3169134: ISRC = DEU240732071
# Processing row 453/3169134: ISRC = HKI190251620
# Processing row 454/3169134: ISRC = QMSGD1470218
# Processing row 455/3169134: ISRC = USBB14101046
# Processing row 456/3169134: ISRC = USBB14201001
# Processing row 457/3169134: ISRC = QMSGD1470215
# Processing row 458/3169134: ISRC = USMC16351954
# Processing row 459/3169134: ISRC = USSM10502225
# Processing row 460/3169134: ISRC = USCA28800762
# Processing row 461/3169134: ISRC = GBHFE0511191
# Processing row 462/3169134: ISRC = USSM15600426
# Processing row 463/3169134: ISRC = GBAYE6200091
# Processing row 464/3169134: ISRC = USYLB0800302
# Processing row 465/3169134: ISRC = USMV20400007
# Processing row 466/3169134: ISRC = DEOB11000044
# Processing row 467/3169134: ISRC = USYLB0800308
# Processing row 468/3169134: ISRC = USYLB0800303
# Processing row 469/3169134: ISRC = USMV20400009
# Processing row 470/3169134: ISRC = QMVYT1100007
# Processing row 471/3169134: ISRC = USYLB0800307
# Processing row 472/3169134: ISRC = USSM18000583
# Processing row 473/3169134: ISRC = USSM18000584
# Processing row 474/3169134: ISRC = USSM18000586
# Processing row 475/3169134: ISRC = NLC050201516
# Processing row 476/3169134: ISRC = GBLMP9800203
# Processing row 477/3169134: ISRC = USJ3V1351312
# Processing row 478/3169134: ISRC = GBBVL1604671
# Processing row 479/3169134: ISRC = DEL021610010
# Processing row 480/3169134: ISRC = usl4q2212525
# Processing row 481/3169134: ISRC = GBANR0000020
# Processing row 482/3169134: ISRC = QZTB72281909
# Processing row 483/3169134: ISRC = QZTB72281916
# Processing row 484/3169134: ISRC = US1A19324601
# Processing row 485/3169134: ISRC = GBLGL0913385
# Processing row 486/3169134: ISRC = USAT20110221
# Processing row 487/3169134: ISRC = DEBL60675754
# Processing row 488/3169134: ISRC = GBLGL0904679
# Processing row 489/3169134: ISRC = USAT20109134
# Processing row 490/3169134: ISRC = USAT20401022
# Processing row 491/3169134: ISRC = USAT20501652
# Processing row 492/3169134: ISRC = NLG620488939
# Processing row 493/3169134: ISRC = USAT20202090
# Processing row 494/3169134: ISRC = USAT20501677
# Processing row 495/3169134: ISRC = USAT20501656
# Processing row 685/3169134: ISRC = SEWXU1713013
# Processing row 686/3169134: ISRC = CAD431091801
# Processing row 687/3169134: ISRC = CAD431091802
# Processing row 688/3169134: ISRC = CAD431091803
# Processing row 689/3169134: ISRC = CAD431091804
# Processing row 690/3169134: ISRC = CAD431091805
# Processing row 691/3169134: ISRC = CAD431091806
# Processing row 692/3169134: ISRC = CAD431091807
# Processing row 693/3169134: ISRC = CAD431091808
# Processing row 694/3169134: ISRC = CAD431091809
# Processing row 695/3169134: ISRC = CAD431091811
# Processing row 696/3169134: ISRC = CAD431091812
# Processing row 697/3169134: ISRC = DENX61088001
# Processing row 698/3169134: ISRC = DENX61088002
# Processing row 699/3169134: ISRC = DENX61088003
# Processing row 700/3169134: ISRC = DENX61088005
# Processing row 701/3169134: ISRC = DENX61088006
# Processing row 702/3169134: ISRC = DENX61088007
# Processing row 703/3169134: ISRC = DENX61088008
# Processing row 704/3169134: ISRC = DENX61088009
# Processing row 705/3169134: ISRC = DENX61088010
# Processing row 706/3169134: ISRC = DENX61088012
# Processing row 707/3169134: ISRC = DENX61088013
# Processing row 708/3169134: ISRC = USBB10200001
# Processing row 709/3169134: ISRC = DEKB71456864
# Processing row 710/3169134: ISRC = USA560933009
# Processing row 711/3169134: ISRC = GBEEJ0601713
# Processing row 712/3169134: ISRC = DEXO52485633
# Processing row 713/3169134: ISRC = FR10S1502494
# Processing row 714/3169134: ISRC = DEA540804871
# Processing row 715/3169134: ISRC = DEXO52485616
# Processing row 716/3169134: ISRC = US2GH9841518
# Processing row 717/3169134: ISRC = AUXN22107746
# Processing row 718/3169134: ISRC = FR10S1502458
# Processing row 719/3169134: ISRC = USCXG1500403
# Processing row 720/3169134: ISRC = ITD561200084
# Processing row 721/3169134: ISRC = USBB10200011
# Processing row 722/3169134: ISRC = SEWDL0453821
# Processing row 723/3169134: ISRC = USA560933041
# Processing row 724/3169134: ISRC = USA370605413
# Processing row 725/3169134: ISRC = GBLPF0271801
# Processing row 726/3169134: ISRC = GBEEJ0601741
# Processing row 727/3169134: ISRC = GBLGL1048360
# Processing row 728/3169134: ISRC = QZXLZ2377469
# Processing row 729/3169134: ISRC = USA560933050
# Processing row 730/3169134: ISRC = FR4GL1071419
# Processing row 731/3169134: ISRC = FR10S1502422
# Processing row 732/3169134: ISRC = GBAJU2000501
# Processing row 733/3169134: ISRC = DEXO52485632
# Processing row 734/3169134: ISRC = GBBMR0923115
# Processing row 735/3169134: ISRC = AUXN22333799
# Processing row 736/3169134: ISRC = GBLGL0820236
# Processing row 737/3169134: ISRC = GBGN31483706
# Processing row 738/3169134: ISRC = USJ3V2091527
# Processing row 739/3169134: ISRC = GBURZ1601658
# Processing row 740/3169134: ISRC = USJ3V2091494
# Processing row 741/3169134: ISRC = GBGN39391811
# Processing row 742/3169134: ISRC = USA560933071
# Processing row 743/3169134: ISRC = FR10S1502435
# Processing row 744/3169134: ISRC = USA370605381
# Processing row 745/3169134: ISRC = GBLGL0982919
# Processing row 746/3169134: ISRC = GBAJU2000507
# Processing row 747/3169134: ISRC = USA560933084
# Processing row 748/3169134: ISRC = USBB10200013
# Processing row 749/3169134: ISRC = UKU6H1951210
# Processing row 750/3169134: ISRC = FR4GL1071405
# Processing row 751/3169134: ISRC = FR10S1502405
# Processing row 752/3169134: ISRC = USCXG1500409
# Processing row 753/3169134: ISRC = ITD561200067
# Processing row 754/3169134: ISRC = GBGN39391805
# Processing row 755/3169134: ISRC = USBB10200005
# Processing row 756/3169134: ISRC = USBB10200008
# Processing row 757/3169134: ISRC = USEWJ1092101
# Processing row 758/3169134: ISRC = FR4GL1071417
# Processing row 759/3169134: ISRC = USBB10000389
# Processing row 760/3169134: ISRC = DEXO52485623
# Processing row 761/3169134: ISRC = DEXO52485637
# Processing row 762/3169134: ISRC = USNO19736302
# Processing row 763/3169134: ISRC = USBB10200010
# Processing row 764/3169134: ISRC = AUXN22109099
# Processing row 765/3169134: ISRC = USSM19901945
# Processing row 766/3169134: ISRC = GBLGL1048359
# Processing row 767/3169134: ISRC = USA560933046
# Processing row 768/3169134: ISRC = USA560933051
# Processing row 769/3169134: ISRC = USA370605421
# Processing row 770/3169134: ISRC = USA560933076
# Processing row 771/3169134: ISRC = GBLGL0981770
# Processing row 772/3169134: ISRC = DEX991792105
# Processing row 773/3169134: ISRC = DEX991792101
# Processing row 774/3169134: ISRC = DEX991792107
# Processing row 775/3169134: ISRC = FRY229804092
# Processing row 776/3169134: ISRC = ES7892300105
# Processing row 777/3169134: ISRC = DEX991792106
# Processing row 778/3169134: ISRC = CH1491329307
# Processing row 779/3169134: ISRC = DEX991792103
# Processing row 780/3169134: ISRC = FRY229804098
# Processing row 781/3169134: ISRC = DEU921064502
# Processing row 782/3169134: ISRC = DEBE20400030
# Processing row 783/3169134: ISRC = DEBE20400031
# Processing row 784/3169134: ISRC = DEBE20400032
# Processing row 785/3169134: ISRC = DEBE20400033
# Processing row 786/3169134: ISRC = DEBE20400034
# Processing row 787/3169134: ISRC = DEBE20400035
# Processing row 788/3169134: ISRC = DEBE20400036
# Processing row 789/3169134: ISRC = DEBE20400037
# Processing row 790/3169134: ISRC = DEBE20400041
# Processing row 791/3169134: ISRC = DEBE20400039
# Processing row 792/3169134: ISRC = DEBE20400040
# Processing row 793/3169134: ISRC = USUM70912464
# Processing row 794/3169134: ISRC = NLP970900010
# Processing row 795/3169134: ISRC = NLC280900196
# Processing row 796/3169134: ISRC = GBUM70810073
# Processing row 797/3169134: ISRC = NLZ542300467
# Processing row 798/3169134: ISRC = GBBBM0002224
# Processing row 799/3169134: ISRC = USA220810970
# Processing row 800/3169134: ISRC = USA220810971
# Processing row 801/3169134: ISRC = USA220810972
# Processing row 802/3169134: ISRC = USA220810973
# Processing row 803/3169134: ISRC = USA220810974
# Processing row 804/3169134: ISRC = USA220810975
# Processing row 805/3169134: ISRC = USA220810976
# Processing row 806/3169134: ISRC = USA220810977
# Processing row 807/3169134: ISRC = USA220810979
# Processing row 808/3169134: ISRC = USA220810980
# Processing row 809/3169134: ISRC = USA220810981
# Processing row 810/3169134: ISRC = USA220810982
# Processing row 811/3169134: ISRC = USA220810983
# Processing row 812/3169134: ISRC = USA220810984
# Processing row 813/3169134: ISRC = USA220810985
# Processing row 814/3169134: ISRC = USA220810986
# Processing row 815/3169134: ISRC = USA220810987
# Processing row 816/3169134: ISRC = USA220810988
# Processing row 817/3169134: ISRC = USA220810989
# Processing row 818/3169134: ISRC = USA220810990
# Processing row 819/3169134: ISRC = USA220810991
# Processing row 820/3169134: ISRC = USA220810992
# Processing row 821/3169134: ISRC = USA220810993
# Processing row 822/3169134: ISRC = USA220810994
# Processing row 823/3169134: ISRC = USA220810995
# Processing row 824/3169134: ISRC = ATV110680006
# Processing row 825/3169134: ISRC = ATV110576002
# Processing row 826/3169134: ISRC = DEF700003264
# Processing row 827/3169134: ISRC = ATV110990002
# Processing row 828/3169134: ISRC = DEA370907098
# Processing row 829/3169134: ISRC = DEA980496709
# Processing row 830/3169134: ISRC = DEC719900740
# Processing row 831/3169134: ISRC = DEC719300001
# Processing row 832/3169134: ISRC = DEC730701269
# Processing row 833/3169134: ISRC = DEC737700071
# Processing row 834/3169134: ISRC = DEW581500040
# Processing row 835/3169134: ISRC = DEA811000868
# Processing row 836/3169134: ISRC = DEA810501602
# Processing row 837/3169134: ISRC = DEHU52300217
# Processing row 838/3169134: ISRC = DEC709900116
# Processing row 839/3169134: ISRC = DEF450842079
# Processing row 840/3169134: ISRC = DEE860200692
# Processing row 841/3169134: ISRC = DER411200052
# Processing row 842/3169134: ISRC = DEC739100041
# Processing row 843/3169134: ISRC = DEKE41562208
# Processing row 844/3169134: ISRC = FR58F7900160
# Processing row 845/3169134: ISRC = CAU118310961
# Processing row 846/3169134: ISRC = CAU118103742
# Processing row 847/3169134: ISRC = FR6V80878788
# Processing row 848/3169134: ISRC = USIR27700004
# Processing row 849/3169134: ISRC = GBBBN7500001
# Processing row 850/3169134: ISRC = USPR38000025
# Processing row 851/3169134: ISRC = CAU118100032
# Processing row 852/3169134: ISRC = DEGH31600024
# Processing row 853/3169134: ISRC = NLD681702435
# Processing row 854/3169134: ISRC = DEAF71108086
# Processing row 855/3169134: ISRC = IT00G0013593
# Processing row 856/3169134: ISRC = TCAFE2001495
# Processing row 857/3169134: ISRC = DEGE91200077
# Processing row 858/3169134: ISRC = DEN060000167
# Processing row 859/3169134: ISRC = DEN060000154
# Processing row 860/3169134: ISRC = DEN061201098
# Processing row 861/3169134: ISRC = DEG840000011
# Processing row 862/3169134: ISRC = DEN120001368
# Processing row 863/3169134: ISRC = UKCVA1804453
# Processing row 864/3169134: ISRC = UKCVA1804449
# Processing row 865/3169134: ISRC = GBAJH0502589
# Processing row 866/3169134: ISRC = GBAJH0502598
# Processing row 867/3169134: ISRC = USIR28600020
# Processing row 868/3169134: ISRC = USIR29000064
# Processing row 869/3169134: ISRC = USIR20000362
# Processing row 870/3169134: ISRC = USIR29100052
# Processing row 871/3169134: ISRC = USIR29000059
# Processing row 872/3169134: ISRC = USIR28600018
# Processing row 873/3169134: ISRC = USIR28600022
# Processing row 874/3169134: ISRC = USIR28800029
# Processing row 875/3169134: ISRC = USWWW0127671
# Processing row 876/3169134: ISRC = USIR29100046
# Processing row 877/3169134: ISRC = USIR28800026
# Processing row 878/3169134: ISRC = USIR20000364
# Processing row 879/3169134: ISRC = USME30900497
# Processing row 880/3169134: ISRC = CHG052400208
# Processing row 881/3169134: ISRC = USIR19701589
# Processing row 882/3169134: ISRC = GBMC19610143
# Processing row 883/3169134: ISRC = ATB159200033
# Processing row 884/3169134: ISRC = USSK31819951
# Processing row 885/3169134: ISRC = USVX41100128
# Processing row 886/3169134: ISRC = GBBHW7829311
# Processing row 887/3169134: ISRC = USSF16151904
# Processing row 888/3169134: ISRC = USRO20283523
# Processing row 889/3169134: ISRC = GBAHX0601867
# Processing row 890/3169134: ISRC = GBAJC9700344
# Processing row 891/3169134: ISRC = QM4TX2169992
# Processing row 892/3169134: ISRC = GBGN32232211
# Processing row 893/3169134: ISRC = DEB518300051
# Processing row 894/3169134: ISRC = DEB518300054
# Processing row 895/3169134: ISRC = US3M50122504
# Processing row 896/3169134: ISRC = DEUM71203310
# Processing row 897/3169134: ISRC = DGA082269854
# Processing row 898/3169134: ISRC = QM4TX2254019
# Processing row 899/3169134: ISRC = USTE10515631
# Processing row 900/3169134: ISRC = USTE10518631
# Processing row 901/3169134: ISRC = USTE10521631
# Processing row 902/3169134: ISRC = QM4TW1875044
# Processing row 903/3169134: ISRC = QM4TW1875128
# Processing row 904/3169134: ISRC = QM4TX2169991
# Processing row 905/3169134: ISRC = HKI191200493
# Processing row 906/3169134: ISRC = US3M51415401
# Processing row 907/3169134: ISRC = FRX201659648
# Processing row 908/3169134: ISRC = GBGRH0800028
# Processing row 909/3169134: ISRC = USUM72407733
# Processing row 910/3169134: ISRC = GBGRH1300085
# Processing row 911/3169134: ISRC = USRN10100176
# Processing row 912/3169134: ISRC = USSM17400679
# Processing row 913/3169134: ISRC = USPR37330006
# Processing row 914/3169134: ISRC = USCRB9900152
# Processing row 915/3169134: ISRC = USRN19600151
# Processing row 916/3169134: ISRC = USSE90320363
# Processing row 917/3169134: ISRC = USUS70400104
# Processing row 918/3169134: ISRC = USSM19921091
# Processing row 919/3169134: ISRC = USSM10403936
# Processing row 920/3169134: ISRC = USSM17700022
# Processing row 921/3169134: ISRC = USMC17807516
# Processing row 922/3169134: ISRC = USSM10012737
# Processing row 923/3169134: ISRC = USSM16801302
# Processing row 924/3169134: ISRC = CZK012500213
# Processing row 925/3169134: ISRC = SETGM9600502
# Processing row 926/3169134: ISRC = DEG189810183
# Processing row 927/3169134: ISRC = DEP399604101
# Processing row 928/3169134: ISRC = GBAYC8600684
# Processing row 929/3169134: ISRC = US4E40596803
# Processing row 930/3169134: ISRC = AUBEC2345116
# Processing row 931/3169134: ISRC = DEZ650610805
# Processing row 932/3169134: ISRC = TCACS1688002
# Processing row 933/3169134: ISRC = GBKQU1397861
# Processing row 934/3169134: ISRC = DEGQ82205824
# Processing row 935/3169134: ISRC = NOHCA1102030
# Processing row 936/3169134: ISRC = USPMZ1104112
# Processing row 937/3169134: ISRC = USPMZ1208708
# Processing row 938/3169134: ISRC = USPMZ1105104
# Processing row 939/3169134: ISRC = USPMZ1208710
# Processing row 940/3169134: ISRC = FRZ115600360
# Processing row 941/3169134: ISRC = FR67W1000055
# Processing row 942/3169134: ISRC = FRZ115700240
