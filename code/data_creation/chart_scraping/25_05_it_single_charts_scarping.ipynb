# %%
'''
author: Alexander Staub
Date: 2025-04-21
Description: Script for scraper of "hitparadeitalia.it", IT charts 

'''

# %%
"""
Scrape IT singles charts  1980-2000
========================================================
Outputs a single CSV with the columns

    chart_type        "singles" 
    chart_date        YYYY-MM-DD (Sunday shown in the URL)
    position          1-20 (or 1-50 if the page shows more)*
    last_week         integer or NaN if not available
    song_title
    artist_name

The script is **checkpoint-aware**: if you stop it midway you can rerun it
and it will skip the weeks already in the CSV.

Requirement summary
-------------------
2) Every available position each week (page displays up to 100)  
4) Produces **one big CSV** in `data/` (relative path)  
5) Works locally & remotely – all paths are relative  
6) Robust to interruptions, rate-limits, and missing weeks  
7) Random 2-3 s delay between *HTTP* requests

© 2025 – academic-use only.  ↝ MIT licence if you wish.
"""

# %%
# installing required packages
from __future__ import annotations

import csv
import random
import time
import re # for regex
from datetime import datetime
from pathlib import Path
from typing import Iterable, List
import logging
from tqdm.notebook import tqdm # for progress bar

import pandas as pd
import requests
from bs4 import BeautifulSoup
from tenacity import retry, stop_after_attempt, wait_random_exponential

# %%
# ──────────────────────────────────────────────────────────────
# CONSTANTS & CONFIG
# ──────────────────────────────────────────────────────────────
BASE_URL = "https://hitparadeitalia.it/hp_weeks/"

# Go three levels up from the current working directory
base_dir = Path.cwd().parents[2]
CSV_PATH = base_dir / "data" / "raw_data" / "country_chart_data" / "it_charts_1980_2000.csv"
CSV_PATH.parent.mkdir(parents=True, exist_ok=True)


HEADERS = {
    "User-Agent": "chart-research/1.0 (+https://github.com/deskreject)",
    "Accept-Language": "en-GB,en;q=0.9",
}


#YEARS = list(range(1979, 2000 + 1)) # full range
Years = list(range(1979, 1985+1)) # limited to unscraped years after first run

REQUEST_DELAY_RANGE = (1, 3.0)  # polite crawling

# --- Add Logging Configuration ---
LOG_PATH = base_dir / "code" / "logs" / "it_charts_scraping.log" # Define log file path
LOG_PATH.parent.mkdir(parents=True, exist_ok=True) # Create logs directory

logging.basicConfig(
    level=logging.DEBUG, # Log INFO, WARNING, ERROR, CRITICAL levels
    format="%(asctime)s [%(levelname)s] %(message)s", # Include timestamp and level
    handlers=[
        logging.FileHandler(LOG_PATH, mode='a'), # Append logs to this file
        logging.StreamHandler() # Also print logs to the console
    ]
)

# %%
# ──────────────────────────────────────────────────────────────
# HTTP helpers
# ──────────────────────────────────────────────────────────────
session = requests.Session()
session.headers.update(HEADERS)


@retry(
    reraise=True,
    stop=stop_after_attempt(5),
    wait=wait_random_exponential(multiplier=1, max=20),
)
def fetch(url: str) -> str:
    """GET a URL with retries & exponential back‑off (tenacity)."""
    resp = session.get(url, timeout=30)
    resp.raise_for_status()
    return resp.text

# %%
# ──────────────────────────────────────────────────────────────
# Chart link extraction and parsing logic
# ──────────────────────────────────────────────────────────────
def get_weekly_chart_links(year):
    """Return [(full_url, date)] for all weeks in given year."""
    index_url = f"{BASE_URL}hpw_{year}.htm"
    try:
        res = session.get(index_url, timeout=10)
        res.raise_for_status()
    except Exception as e:
        logging.error(f"Failed to fetch {index_url}: {e}")
        logging.info(f"{len(links)} weekly links found for year {year}")
        return []

    soup = BeautifulSoup(res.content, "html.parser")
    links = []
    for a in soup.find_all('a', href=True):
        href = a['href']
        match = re.match(r"^(\d{2})/hp(\d{6})\.htm$", href)
        logging.debug(f"Found href: {href}")
        if match:
            year_short, datecode = match.groups()
            full_url = f"{BASE_URL}{href}"
            # Parse date: e.g., hp900106 = 1990-01-06
            dt = datetime.strptime(f"{year_short}{datecode[2:]}", "%y%m%d")
            links.append((full_url, dt.strftime('%Y-%m-%d')))
        else:
            logging.debug(f"Did not match pattern: {href}")
    return links

# %%
# ──────────────────────────────────────────────────────────────
# Progress / resume helpers
# ──────────────────────────────────────────────────────────────

def already_scraped_weeks() -> set[tuple[str, str]]:
    """Read existing CSV (if any) and return {(chart_type, ISO week‑start)}."""
    if not CSV_PATH.exists():
        return set()
    df = pd.read_csv(CSV_PATH, usecols=["chart_type", "chart_week_start"])
    return {(row.chart_type, row.chart_week_start) for row in df.itertuples()}


def append_to_csv(df: pd.DataFrame) -> None:
    header = not CSV_PATH.exists()
    df.to_csv(CSV_PATH, mode="a", index=False, header=header, quoting=csv.QUOTE_MINIMAL)

# %%
#-────────────────────────────────────────────────────────────
# Chart Page Parsing - handling both logics of italian weekly charts
#-────────────────────────────────────────────────────────────

def parse_chart_page(url, chart_date):
    try:
        res = session.get(url, timeout=10)
        res.raise_for_status()
        soup = BeautifulSoup(res.content, "html.parser")
    except Exception as e:
        logging.error(f"Error fetching {url}: {e}")
        return []

    tables = soup.find_all("table")
    rows = []

    # Try table format (modern)
    if len(tables) >= 2:
        chart_table = tables[1]
        trs = chart_table.find_all("tr")
        for tr in trs:
            tds = tr.find_all("td")
            if len(tds) == 4:
                pos_txt = tds[0].get_text(strip=True).replace('.', '').replace('\xa0', '')
                if not pos_txt or not pos_txt[0].isdigit():
                    continue
                try:
                    pos = int(pos_txt)
                except Exception:
                    continue
                last_txt = tds[1].get_text(strip=True)
                try:
                    last = int(last_txt)
                except Exception:
                    last = None
                song = tds[2].get_text(strip=True)
                artist = tds[3].get_text(strip=True)
                rows.append({
                    'chart_type': 'singles',
                    'chart_week_start': chart_date,
                    'position': pos,
                    'last_week': last,
                    'song_title': song,
                    'artist_name': artist
                })
        if rows:
            logging.info(f"Parsed {len(rows)} rows from table in {url} ({chart_date})")
            return rows

    # --- Fallback: raw <ol> parsing (robust to no </li> tags) ---
    ol = soup.find('ol')
    if ol:
        ol_html = str(ol)
        # Find all lines beginning with <li>, case insensitive, greedy to EOL or next tag
        entries = re.findall(r'<li[^>]*>\s*([^<\n\r]+)', ol_html, re.IGNORECASE)
        for pos, entry in enumerate(entries, 1):
            # Split on last dash for song/artist
            if '-' in entry:
                song, artist = [x.strip() for x in entry.rsplit('-', 1)]
            else:
                song, artist = entry.strip(), ""
            rows.append({
                'chart_type': 'singles',
                'chart_week_start': chart_date,
                'position': pos,
                'last_week': None,
                'song_title': song,
                'artist_name': artist
            })
        if rows:
            logging.info(f"Parsed {len(rows)} rows from <ol> via raw parsing in {url} ({chart_date})")
            return rows

    logging.warning(f"No data parsed for {url} ({chart_date})")
    return []

# %%
def main(full_range=True, trial_year=None, save_every=10):
    """Scrape all available singles charts (full_range or trial year)."""
    logging.info("="*20 + " Scraping Script Started " + "="*20)
    done = already_scraped_weeks()
    logging.info(f"Already scraped {len(done):,} week/chart combos.")

    years = YEARS if full_range else [trial_year]
    all_rows = []
    count = 0
    for year in years:
        for url, chart_date in get_weekly_chart_links(year):
            key = ("singles", chart_date)
            if key in done:
                continue
            rows = parse_chart_page(url, chart_date)
            if rows:
                all_rows.extend(rows)
                count += 1
                if count % save_every == 0:
                    pd.DataFrame(all_rows).to_csv(CSV_PATH, mode="a", index=False, header=not CSV_PATH.exists())
                    all_rows = []
            time.sleep(random.uniform(1, 2))
    # Final save
    if all_rows:
        pd.DataFrame(all_rows).to_csv(CSV_PATH, mode="a", index=False, header=not CSV_PATH.exists())
    logging.info(f"Done! Scraped and saved {count:,} weeks.")

# ---------------------------------------------------
# Run cell
# ---------------------------------------------------
main(full_range=True)        # <- set to False to re‑run a 1‑month trial
# Out:
# 2025-05-28 22:21:28,935 [INFO] ==================== Scraping Script Started ====================
# 2025-05-28 22:21:28,957 [INFO] Already scraped 841 week/chart combos.
# 2025-05-28 22:21:28,960 [DEBUG] Resetting dropped connection: hitparadeitalia.it
# 2025-05-28 22:21:29,341 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/hpw_1979.htm HTTP/1.1" 200 2991
# 2025-05-28 22:21:29,349 [DEBUG] Encoding detection: ascii is most likely the one.
# 2025-05-28 22:21:29,353 [DEBUG] Found href: 79/hp790106.htm
# 2025-05-28 22:21:29,355 [DEBUG] Found href: 79/hp790113.htm
# 2025-05-28 22:21:29,356 [DEBUG] Found href: 79/hp790120.htm
# 2025-05-28 22:21:29,357 [DEBUG] Found href: 79/hp790127.htm
# 2025-05-28 22:21:29,358 [DEBUG] Found href: 79/hp790203.htm
# 2025-05-28 22:21:29,358 [DEBUG] Found href: 79/hp790210.htm
# 2025-05-28 22:21:29,358 [DEBUG] Found href: 79/hp790217.htm
# 2025-05-28 22:21:29,358 [DEBUG] Found href: 79/hp790224.htm
# 2025-05-28 22:21:29,358 [DEBUG] Found href: 79/hp790303.htm
# 2025-05-28 22:21:29,365 [DEBUG] Found href: 79/hp790310.htm
# 2025-05-28 22:21:29,366 [DEBUG] Found href: 79/hp790317.htm
# 2025-05-28 22:21:29,368 [DEBUG] Found href: 79/hp790324.htm
# 2025-05-28 22:21:29,369 [DEBUG] Found href: 79/hp790331.htm
# 2025-05-28 22:21:29,371 [DEBUG] Found href: 79/hp790407.htm
# 2025-05-28 22:21:29,372 [DEBUG] Found href: 79/hp790414.htm
# 2025-05-28 22:21:29,374 [DEBUG] Found href: 79/hp790421.htm
# 2025-05-28 22:21:29,375 [DEBUG] Found href: 79/hp790428.htm
# 2025-05-28 22:21:29,375 [DEBUG] Found href: 79/hp790505.htm
# 2025-05-28 22:21:29,377 [DEBUG] Found href: 79/hp790512.htm
# 2025-05-28 22:21:29,378 [DEBUG] Found href: 79/hp790519.htm
# 2025-05-28 22:21:29,378 [DEBUG] Found href: 79/hp790526.htm
# 2025-05-28 22:21:29,378 [DEBUG] Found href: 79/hp790602.htm
# 2025-05-28 22:21:29,378 [DEBUG] Found href: 79/hp790609.htm
# 2025-05-28 22:21:29,383 [DEBUG] Found href: 79/hp790616.htm
# 2025-05-28 22:21:29,385 [DEBUG] Found href: 79/hp790623.htm
# 2025-05-28 22:21:29,386 [DEBUG] Found href: 79/hp790630.htm
# 2025-05-28 22:21:29,388 [DEBUG] Found href: 79/hp790707.htm
# 2025-05-28 22:21:29,390 [DEBUG] Found href: 79/hp790714.htm
# 2025-05-28 22:21:29,391 [DEBUG] Found href: 79/hp790721.htm
# 2025-05-28 22:21:29,392 [DEBUG] Found href: 79/hp790728.htm
# 2025-05-28 22:21:29,393 [DEBUG] Found href: 79/hp790804.htm
# 2025-05-28 22:21:29,393 [DEBUG] Found href: 79/hp790811.htm
# 2025-05-28 22:21:29,396 [DEBUG] Found href: 79/hp790818.htm
# 2025-05-28 22:21:29,397 [DEBUG] Found href: 79/hp790825.htm
# 2025-05-28 22:21:29,397 [DEBUG] Found href: 79/hp790901.htm
# 2025-05-28 22:21:29,400 [DEBUG] Found href: 79/hp790908.htm
# 2025-05-28 22:21:29,401 [DEBUG] Found href: 79/hp790915.htm
# 2025-05-28 22:21:29,403 [DEBUG] Found href: 79/hp790922.htm
# 2025-05-28 22:21:29,405 [DEBUG] Found href: 79/hp790929.htm
# 2025-05-28 22:21:29,406 [DEBUG] Found href: 79/hp791006.htm
# 2025-05-28 22:21:29,408 [DEBUG] Found href: 79/hp791013.htm
# 2025-05-28 22:21:29,410 [DEBUG] Found href: 79/hp791020.htm
# 2025-05-28 22:21:29,411 [DEBUG] Found href: 79/hp791027.htm
# 2025-05-28 22:21:29,412 [DEBUG] Found href: 79/hp791103.htm
# 2025-05-28 22:21:29,413 [DEBUG] Found href: 79/hp791110.htm
# 2025-05-28 22:21:29,415 [DEBUG] Found href: 79/hp791117.htm
# 2025-05-28 22:21:29,424 [DEBUG] Found href: 79/hp791124.htm
# 2025-05-28 22:21:29,426 [DEBUG] Found href: 79/hp791201.htm
# 2025-05-28 22:21:29,427 [DEBUG] Found href: 79/hp791208.htm
# 2025-05-28 22:21:29,429 [DEBUG] Found href: 79/hp791215.htm
# 2025-05-28 22:21:29,432 [DEBUG] Found href: 79/hp791222.htm
# 2025-05-28 22:21:29,433 [DEBUG] Found href: 79/hp791229.htm
# 2025-05-28 22:21:29,527 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790106.htm HTTP/1.1" 200 2087
# 2025-05-28 22:21:29,527 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790106.htm (1979-01-06)
# 2025-05-28 22:21:31,730 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790113.htm HTTP/1.1" 200 2060
# 2025-05-28 22:21:31,731 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790113.htm (1979-01-13)
# 2025-05-28 22:21:32,815 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790120.htm HTTP/1.1" 200 2060
# 2025-05-28 22:21:32,817 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790120.htm (1979-01-20)
# 2025-05-28 22:21:34,856 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790127.htm HTTP/1.1" 200 2073
# 2025-05-28 22:21:34,857 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790127.htm (1979-01-27)
# 2025-05-28 22:21:35,928 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790203.htm HTTP/1.1" 200 2102
# 2025-05-28 22:21:35,935 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790203.htm (1979-02-03)
# 2025-05-28 22:21:37,196 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790210.htm HTTP/1.1" 200 2100
# 2025-05-28 22:21:37,196 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790210.htm (1979-02-10)
# 2025-05-28 22:21:38,568 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790217.htm HTTP/1.1" 200 2096
# 2025-05-28 22:21:38,570 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790217.htm (1979-02-17)
# 2025-05-28 22:21:40,535 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790224.htm HTTP/1.1" 200 2087
# 2025-05-28 22:21:40,538 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790224.htm (1979-02-24)
# 2025-05-28 22:21:42,028 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790303.htm HTTP/1.1" 200 2097
# 2025-05-28 22:21:42,028 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790303.htm (1979-03-03)
# 2025-05-28 22:21:44,092 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790310.htm HTTP/1.1" 200 2097
# 2025-05-28 22:21:44,097 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790310.htm (1979-03-10)
# 2025-05-28 22:21:45,326 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790317.htm HTTP/1.1" 200 2113
# 2025-05-28 22:21:45,330 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790317.htm (1979-03-17)
# 2025-05-28 22:21:47,318 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790324.htm HTTP/1.1" 200 2113
# 2025-05-28 22:21:47,319 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790324.htm (1979-03-24)
# 2025-05-28 22:21:48,486 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790331.htm HTTP/1.1" 200 2117
# 2025-05-28 22:21:48,486 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790331.htm (1979-03-31)
# 2025-05-28 22:21:49,869 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790407.htm HTTP/1.1" 200 2117
# 2025-05-28 22:21:49,878 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790407.htm (1979-04-07)
# 2025-05-28 22:21:51,060 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790414.htm HTTP/1.1" 200 2113
# 2025-05-28 22:21:51,064 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790414.htm (1979-04-14)
# 2025-05-28 22:21:52,186 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790421.htm HTTP/1.1" 200 2113
# 2025-05-28 22:21:52,191 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790421.htm (1979-04-21)
# 2025-05-28 22:21:53,354 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790428.htm HTTP/1.1" 200 2113
# 2025-05-28 22:21:53,359 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790428.htm (1979-04-28)
# 2025-05-28 22:21:54,517 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790505.htm HTTP/1.1" 200 2124
# 2025-05-28 22:21:54,520 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790505.htm (1979-05-05)
# 2025-05-28 22:21:56,168 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790512.htm HTTP/1.1" 200 2109
# 2025-05-28 22:21:56,176 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790512.htm (1979-05-12)
# 2025-05-28 22:21:58,173 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790519.htm HTTP/1.1" 200 2101
# 2025-05-28 22:21:58,176 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790519.htm (1979-05-19)
# 2025-05-28 22:21:59,666 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790526.htm HTTP/1.1" 200 2101
# 2025-05-28 22:21:59,666 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790526.htm (1979-05-26)
# 2025-05-28 22:22:01,612 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790602.htm HTTP/1.1" 200 2110
# 2025-05-28 22:22:01,616 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790602.htm (1979-06-02)
# 2025-05-28 22:22:03,620 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790609.htm HTTP/1.1" 200 2110
# 2025-05-28 22:22:03,624 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790609.htm (1979-06-09)
# 2025-05-28 22:22:04,878 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790616.htm HTTP/1.1" 200 2115
# 2025-05-28 22:22:04,885 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790616.htm (1979-06-16)
# 2025-05-28 22:22:06,936 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790623.htm HTTP/1.1" 200 2104
# 2025-05-28 22:22:06,936 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790623.htm (1979-06-23)
# 2025-05-28 22:22:08,438 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790630.htm HTTP/1.1" 200 2116
# 2025-05-28 22:22:08,447 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790630.htm (1979-06-30)
# 2025-05-28 22:22:10,777 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790707.htm HTTP/1.1" 200 2102
# 2025-05-28 22:22:10,777 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790707.htm (1979-07-07)
# 2025-05-28 22:22:12,267 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790714.htm HTTP/1.1" 200 2089
# 2025-05-28 22:22:12,267 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790714.htm (1979-07-14)
# 2025-05-28 22:22:14,158 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790721.htm HTTP/1.1" 200 2100
# 2025-05-28 22:22:14,161 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790721.htm (1979-07-21)
# 2025-05-28 22:22:16,211 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790728.htm HTTP/1.1" 200 2095
# 2025-05-28 22:22:16,213 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790728.htm (1979-07-28)
# 2025-05-28 22:22:18,120 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790804.htm HTTP/1.1" 200 2077
# 2025-05-28 22:22:18,121 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790804.htm (1979-08-04)
# 2025-05-28 22:22:20,165 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790811.htm HTTP/1.1" 200 2065
# 2025-05-28 22:22:20,169 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790811.htm (1979-08-11)
# 2025-05-28 22:22:21,974 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790818.htm HTTP/1.1" 200 2065
# 2025-05-28 22:22:21,976 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790818.htm (1979-08-18)
# 2025-05-28 22:22:23,767 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790825.htm HTTP/1.1" 200 2075
# 2025-05-28 22:22:23,767 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790825.htm (1979-08-25)
# 2025-05-28 22:22:25,217 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790901.htm HTTP/1.1" 200 2094
# 2025-05-28 22:22:25,219 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790901.htm (1979-09-01)
# 2025-05-28 22:22:26,398 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790908.htm HTTP/1.1" 200 2078
# 2025-05-28 22:22:26,398 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790908.htm (1979-09-08)
# 2025-05-28 22:22:27,666 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790915.htm HTTP/1.1" 200 2078
# 2025-05-28 22:22:27,667 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790915.htm (1979-09-15)
# 2025-05-28 22:22:28,990 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790922.htm HTTP/1.1" 200 2087
# 2025-05-28 22:22:28,990 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790922.htm (1979-09-22)
# 2025-05-28 22:22:30,968 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp790929.htm HTTP/1.1" 200 2087
# 2025-05-28 22:22:30,976 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp790929.htm (1979-09-29)
# 2025-05-28 22:22:32,945 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791006.htm HTTP/1.1" 200 2085
# 2025-05-28 22:22:32,950 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791006.htm (1979-10-06)
# 2025-05-28 22:22:34,938 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791013.htm HTTP/1.1" 200 2094
# 2025-05-28 22:22:34,938 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791013.htm (1979-10-13)
# 2025-05-28 22:22:36,898 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791020.htm HTTP/1.1" 200 2073
# 2025-05-28 22:22:36,902 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791020.htm (1979-10-20)
# 2025-05-28 22:22:38,478 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791027.htm HTTP/1.1" 200 2083
# 2025-05-28 22:22:38,481 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791027.htm (1979-10-27)
# 2025-05-28 22:22:39,760 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791103.htm HTTP/1.1" 200 2108
# 2025-05-28 22:22:39,760 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791103.htm (1979-11-03)
# 2025-05-28 22:22:40,958 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791110.htm HTTP/1.1" 200 2108
# 2025-05-28 22:22:40,967 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791110.htm (1979-11-10)
# 2025-05-28 22:22:42,902 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791117.htm HTTP/1.1" 200 2108
# 2025-05-28 22:22:42,906 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791117.htm (1979-11-17)
# 2025-05-28 22:22:44,226 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791124.htm HTTP/1.1" 200 2095
# 2025-05-28 22:22:44,227 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791124.htm (1979-11-24)
# 2025-05-28 22:22:45,547 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791201.htm HTTP/1.1" 200 2101
# 2025-05-28 22:22:45,547 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791201.htm (1979-12-01)
# 2025-05-28 22:22:47,592 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791208.htm HTTP/1.1" 200 2107
# 2025-05-28 22:22:47,593 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791208.htm (1979-12-08)
# 2025-05-28 22:22:49,587 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791215.htm HTTP/1.1" 200 2107
# 2025-05-28 22:22:49,594 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791215.htm (1979-12-15)
# 2025-05-28 22:22:50,905 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791222.htm HTTP/1.1" 200 2110
# 2025-05-28 22:22:50,908 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791222.htm (1979-12-22)
# 2025-05-28 22:22:52,263 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/79/hp791229.htm HTTP/1.1" 200 2121
# 2025-05-28 22:22:52,266 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/79/hp791229.htm (1979-12-29)
# 2025-05-28 22:22:53,567 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/hpw_1980.htm HTTP/1.1" 200 2990
# 2025-05-28 22:22:53,587 [DEBUG] Encoding detection: ascii is most likely the one.
# 2025-05-28 22:22:53,587 [DEBUG] Found href: 80/hp800105.htm
# 2025-05-28 22:22:53,587 [DEBUG] Found href: 80/hp800112.htm
# 2025-05-28 22:22:53,598 [DEBUG] Found href: 80/hp800119.htm
# 2025-05-28 22:22:53,598 [DEBUG] Found href: 80/hp800126.htm
# 2025-05-28 22:22:53,598 [DEBUG] Found href: 80/hp800202.htm
# 2025-05-28 22:22:53,604 [DEBUG] Found href: 80/hp800209.htm
# 2025-05-28 22:22:53,605 [DEBUG] Found href: 80/hp800216.htm
# 2025-05-28 22:22:53,607 [DEBUG] Found href: 80/hp800223.htm
# 2025-05-28 22:22:53,608 [DEBUG] Found href: 80/hp800301.htm
# 2025-05-28 22:22:53,609 [DEBUG] Found href: 80/hp800308.htm
# 2025-05-28 22:22:53,609 [DEBUG] Found href: 80/hp800315.htm
# 2025-05-28 22:22:53,609 [DEBUG] Found href: 80/hp800322.htm
# 2025-05-28 22:22:53,609 [DEBUG] Found href: 80/hp800329.htm
# 2025-05-28 22:22:53,615 [DEBUG] Found href: 80/hp800405.htm
# 2025-05-28 22:22:53,617 [DEBUG] Found href: 80/hp800412.htm
# 2025-05-28 22:22:53,618 [DEBUG] Found href: 80/hp800419.htm
# 2025-05-28 22:22:53,621 [DEBUG] Found href: 80/hp800426.htm
# 2025-05-28 22:22:53,623 [DEBUG] Found href: 80/hp800503.htm
# 2025-05-28 22:22:53,624 [DEBUG] Found href: 80/hp800510.htm
# 2025-05-28 22:22:53,626 [DEBUG] Found href: 80/hp800517.htm
# 2025-05-28 22:22:53,627 [DEBUG] Found href: 80/hp800524.htm
# 2025-05-28 22:22:53,629 [DEBUG] Found href: 80/hp800531.htm
# 2025-05-28 22:22:53,629 [DEBUG] Found href: 80/hp800607.htm
# 2025-05-28 22:22:53,633 [DEBUG] Found href: 80/hp800614.htm
# 2025-05-28 22:22:53,634 [DEBUG] Found href: 80/hp800621.htm
# 2025-05-28 22:22:53,636 [DEBUG] Found href: 80/hp800628.htm
# 2025-05-28 22:22:53,638 [DEBUG] Found href: 80/hp800705.htm
# 2025-05-28 22:22:53,639 [DEBUG] Found href: 80/hp800712.htm
# 2025-05-28 22:22:53,641 [DEBUG] Found href: 80/hp800719.htm
# 2025-05-28 22:22:53,642 [DEBUG] Found href: 80/hp800726.htm
# 2025-05-28 22:22:53,642 [DEBUG] Found href: 80/hp800802.htm
# 2025-05-28 22:22:53,650 [DEBUG] Found href: 80/hp800809.htm
# 2025-05-28 22:22:53,653 [DEBUG] Found href: 80/hp800816.htm
# 2025-05-28 22:22:53,653 [DEBUG] Found href: 80/hp800823.htm
# 2025-05-28 22:22:53,656 [DEBUG] Found href: 80/hp800830.htm
# 2025-05-28 22:22:53,657 [DEBUG] Found href: 80/hp800906.htm
# 2025-05-28 22:22:53,657 [DEBUG] Found href: 80/hp800913.htm
# 2025-05-28 22:22:53,657 [DEBUG] Found href: 80/hp800920.htm
# 2025-05-28 22:22:53,667 [DEBUG] Found href: 80/hp800927.htm
# 2025-05-28 22:22:53,669 [DEBUG] Found href: 80/hp801004.htm
# 2025-05-28 22:22:53,670 [DEBUG] Found href: 80/hp801011.htm
# 2025-05-28 22:22:53,672 [DEBUG] Found href: 80/hp801018.htm
# 2025-05-28 22:22:53,672 [DEBUG] Found href: 80/hp801025.htm
# 2025-05-28 22:22:53,676 [DEBUG] Found href: 80/hp801101.htm
# 2025-05-28 22:22:53,677 [DEBUG] Found href: 80/hp801108.htm
# 2025-05-28 22:22:53,677 [DEBUG] Found href: 80/hp801115.htm
# 2025-05-28 22:22:53,681 [DEBUG] Found href: 80/hp801122.htm
# 2025-05-28 22:22:53,683 [DEBUG] Found href: 80/hp801129.htm
# 2025-05-28 22:22:53,686 [DEBUG] Found href: 80/hp801206.htm
# 2025-05-28 22:22:53,689 [DEBUG] Found href: 80/hp801213.htm
# 2025-05-28 22:22:53,689 [DEBUG] Found href: 80/hp801220.htm
# 2025-05-28 22:22:53,689 [DEBUG] Found href: 80/hp801227.htm
# 2025-05-28 22:22:53,807 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800105.htm HTTP/1.1" 200 2101
# 2025-05-28 22:22:53,814 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800105.htm (1980-01-05)
# 2025-05-28 22:22:55,582 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800112.htm HTTP/1.1" 200 2086
# 2025-05-28 22:22:55,582 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800112.htm (1980-01-12)
# 2025-05-28 22:22:57,553 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800119.htm HTTP/1.1" 200 2099
# 2025-05-28 22:22:57,556 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800119.htm (1980-01-19)
# 2025-05-28 22:22:58,829 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800126.htm HTTP/1.1" 200 2085
# 2025-05-28 22:22:58,835 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800126.htm (1980-01-26)
# 2025-05-28 22:23:00,688 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800202.htm HTTP/1.1" 200 2087
# 2025-05-28 22:23:00,689 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800202.htm (1980-02-02)
# 2025-05-28 22:23:02,533 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800209.htm HTTP/1.1" 200 2105
# 2025-05-28 22:23:02,536 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800209.htm (1980-02-09)
# 2025-05-28 22:23:03,697 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800216.htm HTTP/1.1" 200 2102
# 2025-05-28 22:23:03,701 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800216.htm (1980-02-16)
# 2025-05-28 22:23:05,728 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800223.htm HTTP/1.1" 200 2120
# 2025-05-28 22:23:05,733 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800223.htm (1980-02-23)
# 2025-05-28 22:23:07,064 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800301.htm HTTP/1.1" 200 2115
# 2025-05-28 22:23:07,069 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800301.htm (1980-03-01)
# 2025-05-28 22:23:08,417 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800308.htm HTTP/1.1" 200 2115
# 2025-05-28 22:23:08,418 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800308.htm (1980-03-08)
# 2025-05-28 22:23:10,194 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800315.htm HTTP/1.1" 200 2089
# 2025-05-28 22:23:10,197 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800315.htm (1980-03-15)
# 2025-05-28 22:23:11,768 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800322.htm HTTP/1.1" 200 2085
# 2025-05-28 22:23:11,768 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800322.htm (1980-03-22)
# 2025-05-28 22:23:13,771 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800329.htm HTTP/1.1" 200 2080
# 2025-05-28 22:23:13,774 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800329.htm (1980-03-29)
# 2025-05-28 22:23:15,668 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800405.htm HTTP/1.1" 200 2085
# 2025-05-28 22:23:15,678 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800405.htm (1980-04-05)
# 2025-05-28 22:23:17,166 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800412.htm HTTP/1.1" 200 2080
# 2025-05-28 22:23:17,168 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800412.htm (1980-04-12)
# 2025-05-28 22:23:18,759 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800419.htm HTTP/1.1" 200 2067
# 2025-05-28 22:23:18,767 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800419.htm (1980-04-19)
# 2025-05-28 22:23:20,388 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800426.htm HTTP/1.1" 200 2067
# 2025-05-28 22:23:20,388 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800426.htm (1980-04-26)
# 2025-05-28 22:23:22,720 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800503.htm HTTP/1.1" 200 2067
# 2025-05-28 22:23:22,720 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800503.htm (1980-05-03)
# 2025-05-28 22:23:24,685 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800510.htm HTTP/1.1" 200 2067
# 2025-05-28 22:23:24,689 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800510.htm (1980-05-10)
# 2025-05-28 22:23:25,930 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800517.htm HTTP/1.1" 200 2067
# 2025-05-28 22:23:25,938 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800517.htm (1980-05-17)
# 2025-05-28 22:23:27,375 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800524.htm HTTP/1.1" 200 2067
# 2025-05-28 22:23:27,378 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800524.htm (1980-05-24)
# 2025-05-28 22:23:29,983 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800531.htm HTTP/1.1" 200 2067
# 2025-05-28 22:23:29,986 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800531.htm (1980-05-31)
# 2025-05-28 22:23:31,900 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800607.htm HTTP/1.1" 200 2048
# 2025-05-28 22:23:31,903 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800607.htm (1980-06-07)
# 2025-05-28 22:23:33,471 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800614.htm HTTP/1.1" 200 2073
# 2025-05-28 22:23:33,474 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800614.htm (1980-06-14)
# 2025-05-28 22:23:35,458 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800621.htm HTTP/1.1" 200 2072
# 2025-05-28 22:23:35,461 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800621.htm (1980-06-21)
# 2025-05-28 22:23:37,283 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800628.htm HTTP/1.1" 200 2058
# 2025-05-28 22:23:37,288 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800628.htm (1980-06-28)
# 2025-05-28 22:23:38,442 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800705.htm HTTP/1.1" 200 2048
# 2025-05-28 22:23:38,446 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800705.htm (1980-07-05)
# 2025-05-28 22:23:40,018 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800712.htm HTTP/1.1" 200 2048
# 2025-05-28 22:23:40,030 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800712.htm (1980-07-12)
# 2025-05-28 22:23:41,930 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800719.htm HTTP/1.1" 200 2049
# 2025-05-28 22:23:41,933 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800719.htm (1980-07-19)
# 2025-05-28 22:23:43,938 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800726.htm HTTP/1.1" 200 2049
# 2025-05-28 22:23:43,941 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800726.htm (1980-07-26)
# 2025-05-28 22:23:45,632 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800802.htm HTTP/1.1" 200 2047
# 2025-05-28 22:23:45,638 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800802.htm (1980-08-02)
# 2025-05-28 22:23:46,850 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800809.htm HTTP/1.1" 200 2070
# 2025-05-28 22:23:46,854 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800809.htm (1980-08-09)
# 2025-05-28 22:23:48,750 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800816.htm HTTP/1.1" 200 2070
# 2025-05-28 22:23:48,750 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800816.htm (1980-08-16)
# 2025-05-28 22:23:50,568 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800823.htm HTTP/1.1" 200 2064
# 2025-05-28 22:23:50,574 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800823.htm (1980-08-23)
# 2025-05-28 22:23:51,905 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800830.htm HTTP/1.1" 200 2064
# 2025-05-28 22:23:51,912 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800830.htm (1980-08-30)
# 2025-05-28 22:23:53,951 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800906.htm HTTP/1.1" 200 2069
# 2025-05-28 22:23:53,951 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800906.htm (1980-09-06)
# 2025-05-28 22:23:55,098 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800913.htm HTTP/1.1" 200 2078
# 2025-05-28 22:23:55,108 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800913.htm (1980-09-13)
# 2025-05-28 22:23:56,183 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800920.htm HTTP/1.1" 200 2078
# 2025-05-28 22:23:56,188 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800920.htm (1980-09-20)
# 2025-05-28 22:23:57,768 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp800927.htm HTTP/1.1" 200 2078
# 2025-05-28 22:23:57,771 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp800927.htm (1980-09-27)
# 2025-05-28 22:23:59,369 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801004.htm HTTP/1.1" 200 2074
# 2025-05-28 22:23:59,380 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801004.htm (1980-10-04)
# 2025-05-28 22:24:00,591 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801011.htm HTTP/1.1" 200 2054
# 2025-05-28 22:24:00,591 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801011.htm (1980-10-11)
# 2025-05-28 22:24:02,210 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801018.htm HTTP/1.1" 200 2054
# 2025-05-28 22:24:02,220 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801018.htm (1980-10-18)
# 2025-05-28 22:24:04,512 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801025.htm HTTP/1.1" 200 2050
# 2025-05-28 22:24:04,512 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801025.htm (1980-10-25)
# 2025-05-28 22:24:06,091 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801101.htm HTTP/1.1" 200 2044
# 2025-05-28 22:24:06,099 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801101.htm (1980-11-01)
# 2025-05-28 22:24:07,989 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801108.htm HTTP/1.1" 200 2042
# 2025-05-28 22:24:08,001 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801108.htm (1980-11-08)
# 2025-05-28 22:24:09,130 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801115.htm HTTP/1.1" 200 2040
# 2025-05-28 22:24:09,130 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801115.htm (1980-11-15)
# 2025-05-28 22:24:10,509 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801122.htm HTTP/1.1" 200 2056
# 2025-05-28 22:24:10,515 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801122.htm (1980-11-22)
# 2025-05-28 22:24:12,240 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801129.htm HTTP/1.1" 200 2056
# 2025-05-28 22:24:12,250 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801129.htm (1980-11-29)
# 2025-05-28 22:24:13,693 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801206.htm HTTP/1.1" 200 2062
# 2025-05-28 22:24:13,696 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801206.htm (1980-12-06)
# 2025-05-28 22:24:15,674 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801213.htm HTTP/1.1" 200 2066
# 2025-05-28 22:24:15,682 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801213.htm (1980-12-13)
# 2025-05-28 22:24:17,556 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801220.htm HTTP/1.1" 200 2081
# 2025-05-28 22:24:17,559 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801220.htm (1980-12-20)
# 2025-05-28 22:24:19,126 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/80/hp801227.htm HTTP/1.1" 200 2083
# 2025-05-28 22:24:19,131 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/80/hp801227.htm (1980-12-27)
# 2025-05-28 22:24:20,863 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/hpw_1981.htm HTTP/1.1" 200 2990
# 2025-05-28 22:24:20,889 [DEBUG] Encoding detection: ascii is most likely the one.
# 2025-05-28 22:24:20,901 [DEBUG] Found href: 81/hp810103.htm
# 2025-05-28 22:24:20,901 [DEBUG] Found href: 81/hp810110.htm
# 2025-05-28 22:24:20,906 [DEBUG] Found href: 81/hp810117.htm
# 2025-05-28 22:24:20,911 [DEBUG] Found href: 81/hp810124.htm
# 2025-05-28 22:24:20,914 [DEBUG] Found href: 81/hp810131.htm
# 2025-05-28 22:24:20,917 [DEBUG] Found href: 81/hp810207.htm
# 2025-05-28 22:24:20,922 [DEBUG] Found href: 81/hp810214.htm
# 2025-05-28 22:24:20,929 [DEBUG] Found href: 81/hp810221.htm
# 2025-05-28 22:24:20,932 [DEBUG] Found href: 81/hp810228.htm
# 2025-05-28 22:24:20,935 [DEBUG] Found href: 81/hp810307.htm
# 2025-05-28 22:24:20,938 [DEBUG] Found href: 81/hp810314.htm
# 2025-05-28 22:24:20,941 [DEBUG] Found href: 81/hp810321.htm
# 2025-05-28 22:24:20,943 [DEBUG] Found href: 81/hp810328.htm
# 2025-05-28 22:24:20,946 [DEBUG] Found href: 81/hp810404.htm
# 2025-05-28 22:24:20,949 [DEBUG] Found href: 81/hp810411.htm
# 2025-05-28 22:24:20,951 [DEBUG] Found href: 81/hp810418.htm
# 2025-05-28 22:24:20,953 [DEBUG] Found href: 81/hp810425.htm
# 2025-05-28 22:24:20,955 [DEBUG] Found href: 81/hp810502.htm
# 2025-05-28 22:24:20,955 [DEBUG] Found href: 81/hp810509.htm
# 2025-05-28 22:24:20,959 [DEBUG] Found href: 81/hp810516.htm
# 2025-05-28 22:24:20,959 [DEBUG] Found href: 81/hp810523.htm
# 2025-05-28 22:24:20,959 [DEBUG] Found href: 81/hp810530.htm
# 2025-05-28 22:24:20,965 [DEBUG] Found href: 81/hp810606.htm
# 2025-05-28 22:24:20,966 [DEBUG] Found href: 81/hp810613.htm
# 2025-05-28 22:24:20,967 [DEBUG] Found href: 81/hp810620.htm
# 2025-05-28 22:24:20,968 [DEBUG] Found href: 81/hp810627.htm
# 2025-05-28 22:24:20,969 [DEBUG] Found href: 81/hp810704.htm
# 2025-05-28 22:24:20,970 [DEBUG] Found href: 81/hp810711.htm
# 2025-05-28 22:24:20,971 [DEBUG] Found href: 81/hp810718.htm
# 2025-05-28 22:24:20,972 [DEBUG] Found href: 81/hp810725.htm
# 2025-05-28 22:24:20,972 [DEBUG] Found href: 81/hp810801.htm
# 2025-05-28 22:24:20,972 [DEBUG] Found href: 81/hp810808.htm
# 2025-05-28 22:24:20,972 [DEBUG] Found href: 81/hp810815.htm
# 2025-05-28 22:24:20,972 [DEBUG] Found href: 81/hp810822.htm
# 2025-05-28 22:24:20,979 [DEBUG] Found href: 81/hp810829.htm
# 2025-05-28 22:24:20,980 [DEBUG] Found href: 81/hp810905.htm
# 2025-05-28 22:24:20,981 [DEBUG] Found href: 81/hp810912.htm
# 2025-05-28 22:24:20,982 [DEBUG] Found href: 81/hp810919.htm
# 2025-05-28 22:24:20,983 [DEBUG] Found href: 81/hp810926.htm
# 2025-05-28 22:24:20,984 [DEBUG] Found href: 81/hp811003.htm
# 2025-05-28 22:24:20,985 [DEBUG] Found href: 81/hp811010.htm
# 2025-05-28 22:24:20,986 [DEBUG] Found href: 81/hp811017.htm
# 2025-05-28 22:24:20,987 [DEBUG] Found href: 81/hp811024.htm
# 2025-05-28 22:24:20,988 [DEBUG] Found href: 81/hp811031.htm
# 2025-05-28 22:24:20,989 [DEBUG] Found href: 81/hp811107.htm
# 2025-05-28 22:24:20,990 [DEBUG] Found href: 81/hp811114.htm
# 2025-05-28 22:24:20,991 [DEBUG] Found href: 81/hp811121.htm
# 2025-05-28 22:24:20,991 [DEBUG] Found href: 81/hp811128.htm
# 2025-05-28 22:24:20,991 [DEBUG] Found href: 81/hp811205.htm
# 2025-05-28 22:24:20,991 [DEBUG] Found href: 81/hp811212.htm
# 2025-05-28 22:24:21,002 [DEBUG] Found href: 81/hp811219.htm
# 2025-05-28 22:24:21,008 [DEBUG] Found href: 81/hp811226.htm
# 2025-05-28 22:24:21,071 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810103.htm HTTP/1.1" 200 2086
# 2025-05-28 22:24:21,071 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810103.htm (1981-01-03)
# 2025-05-28 22:24:22,482 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810110.htm HTTP/1.1" 200 2077
# 2025-05-28 22:24:22,488 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810110.htm (1981-01-10)
# 2025-05-28 22:24:24,189 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810117.htm HTTP/1.1" 200 2061
# 2025-05-28 22:24:24,194 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810117.htm (1981-01-17)
# 2025-05-28 22:24:25,851 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810124.htm HTTP/1.1" 200 2076
# 2025-05-28 22:24:25,851 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810124.htm (1981-01-24)
# 2025-05-28 22:24:27,379 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810131.htm HTTP/1.1" 200 2076
# 2025-05-28 22:24:27,379 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810131.htm (1981-01-31)
# 2025-05-28 22:24:29,121 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810207.htm HTTP/1.1" 200 2091
# 2025-05-28 22:24:29,128 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810207.htm (1981-02-07)
# 2025-05-28 22:24:30,687 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810214.htm HTTP/1.1" 200 2091
# 2025-05-28 22:24:30,691 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810214.htm (1981-02-14)
# 2025-05-28 22:24:32,701 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810221.htm HTTP/1.1" 200 2105
# 2025-05-28 22:24:32,709 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810221.htm (1981-02-21)
# 2025-05-28 22:24:33,923 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810228.htm HTTP/1.1" 200 2116
# 2025-05-28 22:24:33,929 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810228.htm (1981-02-28)
# 2025-05-28 22:24:35,521 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810307.htm HTTP/1.1" 200 2109
# 2025-05-28 22:24:35,530 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810307.htm (1981-03-07)
# 2025-05-28 22:24:37,101 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810314.htm HTTP/1.1" 200 2120
# 2025-05-28 22:24:37,104 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810314.htm (1981-03-14)
# 2025-05-28 22:24:39,099 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810321.htm HTTP/1.1" 200 2122
# 2025-05-28 22:24:39,102 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810321.htm (1981-03-21)
# 2025-05-28 22:24:40,251 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810328.htm HTTP/1.1" 200 2109
# 2025-05-28 22:24:40,259 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810328.htm (1981-03-28)
# 2025-05-28 22:24:41,979 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810404.htm HTTP/1.1" 200 2084
# 2025-05-28 22:24:41,984 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810404.htm (1981-04-04)
# 2025-05-28 22:24:43,982 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810411.htm HTTP/1.1" 200 2087
# 2025-05-28 22:24:43,982 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810411.htm (1981-04-11)
# 2025-05-28 22:24:45,316 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810418.htm HTTP/1.1" 200 2087
# 2025-05-28 22:24:45,320 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810418.htm (1981-04-18)
# 2025-05-28 22:24:46,911 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810425.htm HTTP/1.1" 200 2084
# 2025-05-28 22:24:46,922 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810425.htm (1981-04-25)
# 2025-05-28 22:24:48,271 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810502.htm HTTP/1.1" 200 2084
# 2025-05-28 22:24:48,280 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810502.htm (1981-05-02)
# 2025-05-28 22:24:49,721 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810509.htm HTTP/1.1" 200 2080
# 2025-05-28 22:24:49,721 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810509.htm (1981-05-09)
# 2025-05-28 22:24:51,731 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810516.htm HTTP/1.1" 200 2076
# 2025-05-28 22:24:51,738 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810516.htm (1981-05-16)
# 2025-05-28 22:24:53,323 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810523.htm HTTP/1.1" 200 2076
# 2025-05-28 22:24:53,326 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810523.htm (1981-05-23)
# 2025-05-28 22:24:54,671 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810530.htm HTTP/1.1" 200 2076
# 2025-05-28 22:24:54,674 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810530.htm (1981-05-30)
# 2025-05-28 22:24:56,442 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810606.htm HTTP/1.1" 200 2078
# 2025-05-28 22:24:56,442 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810606.htm (1981-06-06)
# 2025-05-28 22:24:57,695 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810613.htm HTTP/1.1" 200 2065
# 2025-05-28 22:24:57,695 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810613.htm (1981-06-13)
# 2025-05-28 22:24:58,842 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810620.htm HTTP/1.1" 200 2059
# 2025-05-28 22:24:58,843 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810620.htm (1981-06-20)
# 2025-05-28 22:24:59,950 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810627.htm HTTP/1.1" 200 2058
# 2025-05-28 22:24:59,950 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810627.htm (1981-06-27)
# 2025-05-28 22:25:01,616 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810704.htm HTTP/1.1" 200 2056
# 2025-05-28 22:25:01,620 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810704.htm (1981-07-04)
# 2025-05-28 22:25:03,282 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810711.htm HTTP/1.1" 200 2046
# 2025-05-28 22:25:03,285 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810711.htm (1981-07-11)
# 2025-05-28 22:25:05,034 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810718.htm HTTP/1.1" 200 2047
# 2025-05-28 22:25:05,035 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810718.htm (1981-07-18)
# 2025-05-28 22:25:06,569 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810725.htm HTTP/1.1" 200 2044
# 2025-05-28 22:25:06,570 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810725.htm (1981-07-25)
# 2025-05-28 22:25:08,280 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810801.htm HTTP/1.1" 200 2054
# 2025-05-28 22:25:08,284 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810801.htm (1981-08-01)
# 2025-05-28 22:25:10,260 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810808.htm HTTP/1.1" 200 2073
# 2025-05-28 22:25:10,260 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810808.htm (1981-08-08)
# 2025-05-28 22:25:12,101 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810815.htm HTTP/1.1" 200 2073
# 2025-05-28 22:25:12,103 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810815.htm (1981-08-15)
# 2025-05-28 22:25:13,410 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810822.htm HTTP/1.1" 200 2084
# 2025-05-28 22:25:13,410 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810822.htm (1981-08-22)
# 2025-05-28 22:25:15,242 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810829.htm HTTP/1.1" 200 2085
# 2025-05-28 22:25:15,250 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810829.htm (1981-08-29)
# 2025-05-28 22:25:17,543 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810905.htm HTTP/1.1" 200 2090
# 2025-05-28 22:25:17,546 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810905.htm (1981-09-05)
# 2025-05-28 22:25:19,362 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810912.htm HTTP/1.1" 200 2088
# 2025-05-28 22:25:19,370 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810912.htm (1981-09-12)
# 2025-05-28 22:25:20,728 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810919.htm HTTP/1.1" 200 2088
# 2025-05-28 22:25:20,732 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810919.htm (1981-09-19)
# 2025-05-28 22:25:21,893 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp810926.htm HTTP/1.1" 200 2090
# 2025-05-28 22:25:21,895 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp810926.htm (1981-09-26)
# 2025-05-28 22:25:23,151 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp811003.htm HTTP/1.1" 200 2085
# 2025-05-28 22:25:23,152 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp811003.htm (1981-10-03)
# 2025-05-28 22:25:24,951 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp811010.htm HTTP/1.1" 200 2104
# 2025-05-28 22:25:24,951 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp811010.htm (1981-10-10)
# 2025-05-28 22:25:26,764 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp811017.htm HTTP/1.1" 200 2104
# 2025-05-28 22:25:26,764 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp811017.htm (1981-10-17)
# 2025-05-28 22:25:28,791 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp811024.htm HTTP/1.1" 200 2117
# 2025-05-28 22:25:28,791 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp811024.htm (1981-10-24)
# 2025-05-28 22:25:30,102 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp811031.htm HTTP/1.1" 200 2117
# 2025-05-28 22:25:30,112 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp811031.htm (1981-10-31)
# 2025-05-28 22:25:31,191 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp811107.htm HTTP/1.1" 200 2100
# 2025-05-28 22:25:31,200 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/81/hp811107.htm (1981-11-07)
# 2025-05-28 22:25:33,186 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/81/hp811114.htm HTTP/1.1" 200 2102
# ...
# 2025-05-28 22:51:09,536 [DEBUG] Encoding detection: ascii is most likely the one.
# 2025-05-28 22:51:09,551 [DEBUG] Found href: 00/hp000101.htm
# 2025-05-28 22:51:09,553 [DEBUG] Found href: 00/hp000108.htm
# 2025-05-28 22:51:09,555 [DEBUG] Found href: 00/hp000115.htm
# 2025-05-28 22:51:09,557 [DEBUG] Found href: 00/hp000122.htm
# 2025-05-28 22:51:09,559 [DEBUG] Found href: 00/hp000129.htm
# 2025-05-28 22:51:09,561 [DEBUG] Found href: 00/hp000205.htm
# 2025-05-28 22:51:09,562 [DEBUG] Found href: 00/hp000212.htm
# 2025-05-28 22:51:09,565 [DEBUG] Found href: 00/hp000219.htm
# 2025-05-28 22:51:09,567 [DEBUG] Found href: 00/hp000226.htm
# 2025-05-28 22:51:09,568 [DEBUG] Found href: 00/hp000304.htm
# 2025-05-28 22:51:09,570 [DEBUG] Found href: 00/hp000311.htm
# 2025-05-28 22:51:09,570 [DEBUG] Found href: 00/hp000318.htm
# 2025-05-28 22:51:09,572 [DEBUG] Found href: 00/hp000325.htm
# 2025-05-28 22:51:09,572 [DEBUG] Found href: 00/hp000401.htm
# 2025-05-28 22:51:09,574 [DEBUG] Found href: 00/hp000408.htm
# 2025-05-28 22:51:09,576 [DEBUG] Found href: 00/hp000415.htm
# 2025-05-28 22:51:09,578 [DEBUG] Found href: 00/hp000422.htm
# 2025-05-28 22:51:09,579 [DEBUG] Found href: 00/hp000429.htm
# 2025-05-28 22:51:09,582 [DEBUG] Found href: 00/hp000506.htm
# 2025-05-28 22:51:09,583 [DEBUG] Found href: 00/hp000513.htm
# 2025-05-28 22:51:09,585 [DEBUG] Found href: 00/hp000520.htm
# 2025-05-28 22:51:09,586 [DEBUG] Found href: 00/hp000527.htm
# 2025-05-28 22:51:09,588 [DEBUG] Found href: 00/hp000603.htm
# 2025-05-28 22:51:09,589 [DEBUG] Found href: 00/hp000610.htm
# 2025-05-28 22:51:09,590 [DEBUG] Found href: 00/hp000617.htm
# 2025-05-28 22:51:09,591 [DEBUG] Found href: 00/hp000624.htm
# 2025-05-28 22:51:09,592 [DEBUG] Found href: 00/hp000701.htm
# 2025-05-28 22:51:09,593 [DEBUG] Found href: 00/hp000708.htm
# 2025-05-28 22:51:09,594 [DEBUG] Found href: 00/hp000715.htm
# 2025-05-28 22:51:09,596 [DEBUG] Found href: 00/hp000722.htm
# 2025-05-28 22:51:09,597 [DEBUG] Found href: 00/hp000729.htm
# 2025-05-28 22:51:09,599 [DEBUG] Found href: 00/hp000805.htm
# 2025-05-28 22:51:09,600 [DEBUG] Found href: 00/hp000812.htm
# 2025-05-28 22:51:09,601 [DEBUG] Found href: 00/hp000819.htm
# 2025-05-28 22:51:09,604 [DEBUG] Found href: 00/hp000826.htm
# 2025-05-28 22:51:09,605 [DEBUG] Found href: 00/hp000902.htm
# 2025-05-28 22:51:09,607 [DEBUG] Found href: 00/hp000909.htm
# 2025-05-28 22:51:09,608 [DEBUG] Found href: 00/hp000916.htm
# 2025-05-28 22:51:09,610 [DEBUG] Found href: 00/hp000923.htm
# 2025-05-28 22:51:09,612 [DEBUG] Found href: 00/hp000930.htm
# 2025-05-28 22:51:09,623 [DEBUG] Found href: 00/hp001007.htm
# 2025-05-28 22:51:09,625 [DEBUG] Found href: 00/hp001014.htm
# 2025-05-28 22:51:09,627 [DEBUG] Found href: 00/hp001021.htm
# 2025-05-28 22:51:09,628 [DEBUG] Found href: 00/hp001028.htm
# 2025-05-28 22:51:09,636 [DEBUG] Found href: 00/hp001104.htm
# 2025-05-28 22:51:09,638 [DEBUG] Found href: 00/hp001111.htm
# 2025-05-28 22:51:09,639 [DEBUG] Found href: 00/hp001118.htm
# 2025-05-28 22:51:09,643 [DEBUG] Found href: 00/hp001125.htm
# 2025-05-28 22:51:09,645 [DEBUG] Found href: 00/hp001202.htm
# 2025-05-28 22:51:09,647 [DEBUG] Found href: 00/hp001209.htm
# 2025-05-28 22:51:09,650 [DEBUG] Found href: 00/hp001216.htm
# 2025-05-28 22:51:09,668 [DEBUG] Found href: 00/hp001223.htm
# 2025-05-28 22:51:09,670 [DEBUG] Found href: 00/hp001230.htm
# 2025-05-28 22:51:09,796 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000101.htm HTTP/1.1" 200 4346
# 2025-05-28 22:51:09,807 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000101.htm (2000-01-01)
# 2025-05-28 22:51:11,337 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000108.htm HTTP/1.1" 200 4329
# 2025-05-28 22:51:11,350 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000108.htm (2000-01-08)
# 2025-05-28 22:51:13,028 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000115.htm HTTP/1.1" 200 4377
# 2025-05-28 22:51:13,036 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000115.htm (2000-01-15)
# 2025-05-28 22:51:14,911 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000122.htm HTTP/1.1" 200 4359
# 2025-05-28 22:51:14,926 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000122.htm (2000-01-22)
# 2025-05-28 22:51:16,639 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000129.htm HTTP/1.1" 200 4353
# 2025-05-28 22:51:16,646 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000129.htm (2000-01-29)
# 2025-05-28 22:51:17,953 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000205.htm HTTP/1.1" 200 4346
# 2025-05-28 22:51:17,958 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000205.htm (2000-02-05)
# 2025-05-28 22:51:19,897 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000212.htm HTTP/1.1" 200 4334
# 2025-05-28 22:51:19,908 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000212.htm (2000-02-12)
# 2025-05-28 22:51:21,922 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000219.htm HTTP/1.1" 200 4323
# 2025-05-28 22:51:21,927 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000219.htm (2000-02-19)
# 2025-05-28 22:51:23,152 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000226.htm HTTP/1.1" 200 4308
# 2025-05-28 22:51:23,157 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000226.htm (2000-02-26)
# 2025-05-28 22:51:24,327 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000304.htm HTTP/1.1" 200 4244
# 2025-05-28 22:51:24,336 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000304.htm (2000-03-04)
# 2025-05-28 22:51:26,209 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000311.htm HTTP/1.1" 200 4241
# 2025-05-28 22:51:26,217 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000311.htm (2000-03-11)
# 2025-05-28 22:51:27,338 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000318.htm HTTP/1.1" 200 4255
# 2025-05-28 22:51:27,348 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000318.htm (2000-03-18)
# 2025-05-28 22:51:28,622 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000325.htm HTTP/1.1" 200 4257
# 2025-05-28 22:51:28,635 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000325.htm (2000-03-25)
# 2025-05-28 22:51:30,313 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000401.htm HTTP/1.1" 200 4266
# 2025-05-28 22:51:30,332 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000401.htm (2000-04-01)
# 2025-05-28 22:51:31,606 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000408.htm HTTP/1.1" 200 4278
# 2025-05-28 22:51:31,630 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000408.htm (2000-04-08)
# 2025-05-28 22:51:33,440 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000415.htm HTTP/1.1" 200 4263
# 2025-05-28 22:51:33,452 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000415.htm (2000-04-15)
# 2025-05-28 22:51:35,517 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000422.htm HTTP/1.1" 200 4269
# 2025-05-28 22:51:35,523 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000422.htm (2000-04-22)
# 2025-05-28 22:51:36,724 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000429.htm HTTP/1.1" 200 4263
# 2025-05-28 22:51:36,735 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000429.htm (2000-04-29)
# 2025-05-28 22:51:38,270 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000506.htm HTTP/1.1" 200 4272
# 2025-05-28 22:51:38,270 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000506.htm (2000-05-06)
# 2025-05-28 22:51:40,127 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000513.htm HTTP/1.1" 200 4282
# 2025-05-28 22:51:40,146 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000513.htm (2000-05-13)
# 2025-05-28 22:51:41,785 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000520.htm HTTP/1.1" 200 4319
# 2025-05-28 22:51:41,801 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000520.htm (2000-05-20)
# 2025-05-28 22:51:43,957 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000527.htm HTTP/1.1" 200 4273
# 2025-05-28 22:51:43,976 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000527.htm (2000-05-27)
# 2025-05-28 22:51:45,074 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000603.htm HTTP/1.1" 200 4248
# 2025-05-28 22:51:45,091 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000603.htm (2000-06-03)
# 2025-05-28 22:51:46,475 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000610.htm HTTP/1.1" 200 4250
# 2025-05-28 22:51:46,492 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000610.htm (2000-06-10)
# 2025-05-28 22:51:48,160 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000617.htm HTTP/1.1" 200 4284
# 2025-05-28 22:51:48,169 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000617.htm (2000-06-17)
# 2025-05-28 22:51:49,878 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000624.htm HTTP/1.1" 200 4311
# 2025-05-28 22:51:49,878 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000624.htm (2000-06-24)
# 2025-05-28 22:51:51,719 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000701.htm HTTP/1.1" 200 4300
# 2025-05-28 22:51:51,719 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000701.htm (2000-07-01)
# 2025-05-28 22:51:53,633 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000708.htm HTTP/1.1" 200 4256
# 2025-05-28 22:51:53,640 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000708.htm (2000-07-08)
# 2025-05-28 22:51:55,187 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000715.htm HTTP/1.1" 200 4296
# 2025-05-28 22:51:55,200 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000715.htm (2000-07-15)
# 2025-05-28 22:51:56,390 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000722.htm HTTP/1.1" 200 4260
# 2025-05-28 22:51:56,401 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000722.htm (2000-07-22)
# 2025-05-28 22:51:58,275 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000729.htm HTTP/1.1" 200 4250
# 2025-05-28 22:51:58,288 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000729.htm (2000-07-29)
# 2025-05-28 22:52:00,153 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000805.htm HTTP/1.1" 200 4262
# 2025-05-28 22:52:00,172 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000805.htm (2000-08-05)
# 2025-05-28 22:52:02,121 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000812.htm HTTP/1.1" 200 4283
# 2025-05-28 22:52:02,139 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000812.htm (2000-08-12)
# 2025-05-28 22:52:03,355 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000819.htm HTTP/1.1" 200 4270
# 2025-05-28 22:52:03,373 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000819.htm (2000-08-19)
# 2025-05-28 22:52:04,812 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000826.htm HTTP/1.1" 200 4270
# 2025-05-28 22:52:04,825 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000826.htm (2000-08-26)
# 2025-05-28 22:52:06,124 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000902.htm HTTP/1.1" 200 4264
# 2025-05-28 22:52:06,140 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000902.htm (2000-09-02)
# 2025-05-28 22:52:07,449 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000909.htm HTTP/1.1" 200 4276
# 2025-05-28 22:52:07,453 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000909.htm (2000-09-09)
# 2025-05-28 22:52:08,856 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000916.htm HTTP/1.1" 200 4272
# 2025-05-28 22:52:08,859 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000916.htm (2000-09-16)
# 2025-05-28 22:52:11,194 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000923.htm HTTP/1.1" 200 4275
# 2025-05-28 22:52:11,209 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000923.htm (2000-09-23)
# 2025-05-28 22:52:13,067 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp000930.htm HTTP/1.1" 200 4269
# 2025-05-28 22:52:13,073 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp000930.htm (2000-09-30)
# 2025-05-28 22:52:14,358 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001007.htm HTTP/1.1" 200 4260
# 2025-05-28 22:52:14,364 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001007.htm (2000-10-07)
# 2025-05-28 22:52:15,535 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001014.htm HTTP/1.1" 200 4282
# 2025-05-28 22:52:15,553 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001014.htm (2000-10-14)
# 2025-05-28 22:52:17,549 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001021.htm HTTP/1.1" 200 4272
# 2025-05-28 22:52:17,561 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001021.htm (2000-10-21)
# 2025-05-28 22:52:19,170 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001028.htm HTTP/1.1" 200 4282
# 2025-05-28 22:52:19,183 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001028.htm (2000-10-28)
# 2025-05-28 22:52:20,869 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001104.htm HTTP/1.1" 200 4263
# 2025-05-28 22:52:20,869 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001104.htm (2000-11-04)
# 2025-05-28 22:52:23,204 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001111.htm HTTP/1.1" 200 4277
# 2025-05-28 22:52:23,210 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001111.htm (2000-11-11)
# 2025-05-28 22:52:25,045 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001118.htm HTTP/1.1" 200 4247
# 2025-05-28 22:52:25,055 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001118.htm (2000-11-18)
# 2025-05-28 22:52:26,291 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001125.htm HTTP/1.1" 200 4219
# 2025-05-28 22:52:26,308 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001125.htm (2000-11-25)
# 2025-05-28 22:52:27,658 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001202.htm HTTP/1.1" 200 4303
# 2025-05-28 22:52:27,674 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001202.htm (2000-12-02)
# 2025-05-28 22:52:28,810 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001209.htm HTTP/1.1" 200 4270
# 2025-05-28 22:52:28,817 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001209.htm (2000-12-09)
# 2025-05-28 22:52:30,693 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001216.htm HTTP/1.1" 200 4253
# 2025-05-28 22:52:30,710 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001216.htm (2000-12-16)
# 2025-05-28 22:52:32,463 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001223.htm HTTP/1.1" 200 4319
# 2025-05-28 22:52:32,471 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001223.htm (2000-12-23)
# 2025-05-28 22:52:34,429 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/00/hp001230.htm HTTP/1.1" 200 4281
# 2025-05-28 22:52:34,429 [INFO] Parsed 20 rows from table in https://hitparadeitalia.it/hp_weeks/00/hp001230.htm (2000-12-30)
# 2025-05-28 22:52:35,913 [INFO] Done! Scraped and saved 1,143 weeks.

# %% [markdown]
# # Running a 1 month / 1 year trial

# %%
#-------------
# setup of trial
#--------------

# Set this to your chosen year for trial
trial_year = 1979  # change as needed

# %%
# testing on singles charts

main(full_range=False, trial_year=trial_year, save_every=5)
# Out:
# 2025-05-28 22:20:22,155 [INFO] ==================== Scraping Script Started ====================
# 2025-05-28 22:20:22,183 [INFO] Already scraped 841 week/chart combos.
# 2025-05-28 22:20:22,767 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/hpw_%5B1979,%201980,%201981,%201982,%201983,%201984,%201985%5D.htm HTTP/1.1" 404 268
# 2025-05-28 22:20:22,767 [ERROR] Failed to fetch https://hitparadeitalia.it/hp_weeks/hpw_[1979, 1980, 1981, 1982, 1983, 1984, 1985].htm: 404 Client Error: Not Found for url: https://hitparadeitalia.it/hp_weeks/hpw_%5B1979,%201980,%201981,%201982,%201983,%201984,%201985%5D.htm
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 9, in get_weekly_chart_links(year)
#       8     res = session.get(index_url, timeout=10)
# ----> 9     res.raise_for_status()
#      10 except Exception as e:
#
# File c:\Users\astaub1\AppData\Local\anaconda3\envs\music_data_chartmetric\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://hitparadeitalia.it/hp_weeks/hpw_%5B1979,%201980,%201981,%201982,%201983,%201984,%201985%5D.htm
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[28], line 3
#       1 # testing on singles charts
# ----> 3 main(full_range=False, trial_year=trial_year, save_every=5)
#
# Cell In[18], line 11, in main(full_range, trial_year, save_every)
#       9 count = 0
#      10 for year in years:
# ---> 11     for url, chart_date in get_weekly_chart_links(year):
#      12         key = ("singles", chart_date)
#      13         if key in done:
#
# Cell In[4], line 12, in get_weekly_chart_links(year)
#      10 except Exception as e:
#      11     logging.error(f"Failed to fetch {index_url}: {e}")
# ---> 12     logging.info(f"{len(links)} weekly links found for year {year}")
#      13     return []
#      15 soup = BeautifulSoup(res.content, "html.parser")
#
# UnboundLocalError: cannot access local variable 'links' where it is not associated with a value

# %%
#________________________
# debugging steps
#_____________________

# %%
url = "https://hitparadeitalia.it/hp_weeks/90/hp900106.htm"
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

# Print all tables with their index
for idx, table in enumerate(soup.find_all("table")):
    print(f"TABLE {idx}\n{'-'*40}")
    print(table.prettify()[:1500])  # print first 1500 chars for brevity

# %%
# Assume target table is e.g. tables[1], replace with correct index
target_table = soup.find_all("table")[1]  # try 2, 3, 4 if needed

rows = target_table.find_all("tr")
print(f"Found {len(rows)} rows in table {2}")
for idx, tr in enumerate(rows):
    tds = tr.find_all("td")
    print(f"Row {idx}: {len(tds)} columns, values: {[td.get_text(strip=True) for td in tds]}")

# %%
#-----------
# debugging the old chart format
#-----------

test_url = "https://hitparadeitalia.it/hp_weeks/82/hp820102.htm"
rows = parse_chart_page(test_url, "1/2/1982")
for row in rows:
    print(row)
# Out:
# 2025-05-28 22:16:53,116 [DEBUG] Resetting dropped connection: hitparadeitalia.it
# 2025-05-28 22:16:53,411 [DEBUG] https://hitparadeitalia.it:443 "GET /hp_weeks/82/hp820102.htm HTTP/1.1" 200 2097
# 2025-05-28 22:16:53,413 [INFO] Parsed 10 rows from <ol> via raw parsing in https://hitparadeitalia.it/hp_weeks/82/hp820102.htm (1/2/1982)
# {'chart_type': 'singles', 'chart_week_start': '1/2/1982', 'position': 1, 'last_week': None, 'song_title': 'Cicale', 'artist_name': 'Heather Parisi'}
# {'chart_type': 'singles', 'chart_week_start': '1/2/1982', 'position': 2, 'last_week': None, 'song_title': 'Reality', 'artist_name': 'Richard Sanderson'}
# {'chart_type': 'singles', 'chart_week_start': '1/2/1982', 'position': 3, 'last_week': None, 'song_title': 'Sharazan', 'artist_name': 'Al Bano e Romina'}
# {'chart_type': 'singles', 'chart_week_start': '1/2/1982', 'position': 4, 'last_week': None, 'song_title': "You can't stay the night", 'artist_name': 'Miguel Bosè'}
# {'chart_type': 'singles', 'chart_week_start': '1/2/1982', 'position': 5, 'last_week': None, 'song_title': 'Bette Davis eyes', 'artist_name': 'Kim Carnes'}
# {'chart_type': 'singles', 'chart_week_start': '1/2/1982', 'position': 6, 'last_week': None, 'song_title': 'Every little thing she does..', 'artist_name': 'Police'}
# {'chart_type': 'singles', 'chart_week_start': '1/2/1982', 'position': 7, 'last_week': None, 'song_title': 'Lo stellone', 'artist_name': 'Sbirulino'}
# {'chart_type': 'singles', 'chart_week_start': '1/2/1982', 'position': 8, 'last_week': None, 'song_title': "M'innamoro di te", 'artist_name': 'ricchi e poveri'}
# {'chart_type': 'singles', 'chart_week_start': '1/2/1982', 'position': 9, 'last_week': None, 'song_title': 'Lo devo solo a te', 'artist_name': 'Pupo'}
# {'chart_type': 'singles', 'chart_week_start': '1/2/1982', 'position': 10, 'last_week': None, 'song_title': "Arthur's theme", 'artist_name': 'Christopher Cross'}
